# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Modeling</span>

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Setup</span>

# %%
# Python library import block
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# Encoders and other important functions
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
#from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score

# Custom functions from module
from extra_functions import cprint # colored print; makes some output a bit easier to read
from extra_functions import plotColumnCounts # bar plots (categorical) or histograms (numerical) for columns
from extra_functions import trim_feature # remove categories from a model if the total proportion represented is under a certain threshold (default: 1%)
from extra_functions import convert_range_to_avg

# %%
# import data objects for easy indexing
mainline_model = ['website_bool', 'support_url_bool', 'supported_languages_int', 'full_audio_languages_int']
target_features = ['price_log']
target_transformation = {'square_root': 'price'}

# %%
# import data from .csv files
df = pd.read_csv('data/model_mainline games.zip', compression = 'zip').set_index('AppID')
mainline_df = df[mainline_model]
catgen_df = pd.read_csv('data/model_catgen.csv').set_index('AppID')
tags_num_df = pd.read_csv('data/model_tags_numeric.csv').set_index('index')
tags_bool_df = pd.read_csv('data/model_tags_bool.csv').set_index('index')

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Preparation</span>

# %% [markdown]
# I have four predictive models that I can test, that may be able to be combined. At the moment, I will keep them separate to reduce dimensionality during modeling.
#
# - Mainline model: DF with 5 features realted to whether gaves have a website, support information, and how many langauges they have available.
# - Categories/Genres model: DF with 64 game categories and genres. All Boolean, so 1/0.
# - Tags - Numeric model: DF with 30 features, consisting of the 30 most present game tags. This has the raw number of tags per game.
# - Tags - Boolean model: DF with 30 features, like the 'Tags - Numeric model', but all values are 1/0.
#
# After initial modeling, I may take the highest-performing features and run one final model, including everything.
#
# I have one target feature:
# - `price_log`: The natural log of the price (transformed to make the variable a bit more normal)

# %% [markdown]
# **Strategy**:
# There are two classes of models I will be using.
# - Regression: To predict `price_log`. Use multiple regression for these to begin with.
#
# For modeling, I will use cross-validation methods, and have a final holdout sample to see how well the model performs.
#
# **Transformation steps**
# The following steps will be conducted to transform and prep the data for modeling:
#
# 1) Set aside 10% of the data for testing final models
# 2) Set up modeling pipelines
# 3) Model data

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Feature Transformation Prep

# %%
target_df = df[target_features]
target_df.head()
# Out:
#          price_log
# AppID
# 359550    2.995232
# 252490    3.688629
# 1091500   3.400864
# 553850    3.688629
# 413150    2.707383

# %%
X_main, X2_main, X_catgen, X2_catgen, X_tags_num, X2_tags_num, X_tags_bool, X2_tags_bool, y_train, y_test  = train_test_split(mainline_df, catgen_df, tags_num_df, tags_bool_df, target_df, test_size = 0.1, random_state = 42)
print(X_main.shape[0])
print(X2_main.shape[0])
# Out:
# 14296
# 1589

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Modeling Pipelines</span>

# %% [markdown]
# Create column transformers and pipelines for each of the four predictive models.

# %%
main_ct = ColumnTransformer(
    transformers = [('std', StandardScaler(), X_main.columns)],
    remainder = 'passthrough')
tags_num_ct = ColumnTransformer(
    transformers = [('std', StandardScaler(), X_tags_num.columns)],
    remainder = 'passthrough')

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Models - Linear Regression</span>

# %%
main_pipe_ridge = Pipeline([('xform', main_ct), ('ridge', Ridge())])
catgen_pipe_ridge = Pipeline([('poly', PolynomialFeatures(degree = 2, include_bias = False)), ('ridge', Ridge())])
tags_num_ridge = Pipeline([('xform', tags_num_ct,), ('ridge', Ridge())])
tags_bool_ridge = Pipeline([('ridge', Ridge())])

# %% [markdown]
# #### <span style="color: Teal; font-weight: bold">Modeling</span>

# %%
target_features
# Out:
# ['price_log']

# %%
best_price_features = {}

# %%
## Mainline model
ridge_parameters = {'ridge__alpha': 10**np.linspace(-3, 3, 7)}

main_grid_ridge = GridSearchCV(main_pipe_ridge, ridge_parameters, cv = 5, scoring='r2', verbose=1)
main_grid_ridge.fit(X_main, y_train['price_log'])
main_grid_ridge.score(X2_main, y_test['price_log'])
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# 0.02029148178570328

# %%
main_ridge_results = pd.DataFrame({'feature': main_grid_ridge.feature_names_in_, 'coef': main_grid_ridge.best_estimator_['ridge'].coef_}).set_index('feature')
main_ridge_results.sort_values('coef', ascending = False)
# Out:
#                               coef
# feature
# supported_languages_int   0.048248
# support_url_bool          0.020613
# website_bool              0.019944
# full_audio_languages_int  0.007206

# %%
best_price_features['main'] = list(main_ridge_results.index[np.abs(main_ridge_results['coef']) > .05])
best_price_features
# Out:
# {'main': []}

# %%
## Catgen model
ridge_parameters = {'ridge__alpha': 10**np.linspace(-3, 3, 7)}

catgen_grid_ridge = GridSearchCV(catgen_pipe_ridge, ridge_parameters, cv = 5, scoring='r2', verbose=1)
catgen_grid_ridge.fit(X_catgen, y_train['price_log'])
catgen_grid_ridge.score(X2_catgen, y_test['price_log'])
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# 0.12941585106438303

# %%
catgen_ridge_results = pd.DataFrame({'feature': catgen_grid_ridge.best_estimator_.named_steps['poly'].get_feature_names_out(), 'coef': catgen_grid_ridge.best_estimator_['ridge'].coef_}).set_index('feature')
catgen_ridge_results.sort_values('coef',ascending=False)
# Out:
#                                                         coef
# feature
# genres_indie genres_casual                          0.055904
# categories_full_controller_support categories_s...  0.054783
# categories_steam_achievements categories_partia...  0.052557
# categories_single-player categories_multi-player    0.050585
# categories_steam_achievements genres_rpg            0.047097
# categories_steam_cloud genres_adventure             0.046754
# genres_rpg genres_early_access                      0.044985
# genres_indie genres_early_access                    0.043964
# categories_online_pvp categories_full_controlle...  0.039808
# categories_steam_trading_cards genres_strategy      0.036345
# categories_steam_achievements genres_action         0.034451
# categories_multi-player categories_partial_cont...  0.034433
# categories_steam_cloud genres_strategy              0.033997
# categories_multi-player genres_strategy             0.033507
# categories_family_sharing genres_simulation         0.033490
# categories_steam_trading_cards genres_early_access  0.031942
# categories_steam_trading_cards^2                    0.031786
# categories_steam_trading_cards                      0.031786
# categories_single-player categories_remote_play...  0.031112
# genres_action genres_rpg                            0.030750
# categories_multi-player categories_steam_achiev...  0.029690
# categories_full_controller_support genres_rpg       0.029050
# genres_indie genres_strategy                        0.028595
# categories_remote_play_together genres_casual       0.028450
# categories_steam_achievements categories_shared...  0.028352
# categories_online_pvp genres_action                 0.028067
# categories_full_controller_support categories_s...  0.027465
# categories_steam_trading_cards categories_steam...  0.025795
# categories_full_controller_support genres_adven...  0.025051
# genres_early_access genres_strategy                 0.024523
# categories_single-player categories_steam_cloud     0.024013
# genres_indie genres_simulation                      0.023997
# categories_family_sharing categories_remote_pla...  0.023561
# categories_online_pvp categories_shared/split_s...  0.022969
# categories_partial_controller_support genres_rpg    0.022548
# categories_steam_cloud categories_partial_contr...  0.022489
# categories_steam_cloud genres_simulation            0.022369
# categories_online_pvp categories_steam_achievem...  0.022029
# categories_steam_trading_cards genres_rpg           0.020215
# categories_multi-player                             0.018668
# categories_multi-player^2                           0.018668
# categories_single-player categories_steam_achie...  0.018312
# categories_partial_controller_support genres_ea...  0.017959
# genres_action genres_adventure                      0.017402
# categories_multi-player categories_full_control...  0.016904
# categories_single-player categories_shared/spli...  0.016757
# categories_single-player categories_online_pvp      0.016008
# categories_shared/split_screen genres_casual        0.015670
# categories_full_controller_support genres_simul...  0.015398
# categories_online_pvp categories_steam_trading_...  0.014890
# categories_multi-player genres_rpg                  0.014882
# categories_online_pvp genres_rpg                    0.014450
# categories_full_controller_support categories_s...  0.014090
# genres_action genres_casual                         0.013677
# categories_multi-player genres_simulation           0.013387
# categories_single-player genres_simulation          0.012896
# categories_steam_cloud^2                            0.012583
# categories_steam_cloud                              0.012583
# categories_steam_cloud categories_family_sharing    0.011670
# categories_steam_trading_cards categories_famil...  0.011438
# categories_remote_play_together^2                   0.011058
# categories_remote_play_together                     0.011058
# genres_adventure^2                                  0.010662
# genres_adventure                                    0.010662
# categories_partial_controller_support genres_ad...  0.010502
# categories_single-player categories_full_contro...  0.009733
# categories_family_sharing genres_strategy           0.009718
# categories_multi-player categories_steam_cloud      0.009494
# categories_remote_play_together genres_indie        0.009129
# genres_indie genres_rpg                             0.008361
# genres_adventure genres_casual                      0.007825
# categories_full_controller_support genres_action    0.007733
# genres_action                                       0.007179
# genres_action^2                                     0.007179
# categories_shared/split_screen genres_adventure     0.006555
# categories_steam_cloud categories_shared/split_...  0.006373
# categories_steam_achievements                       0.006340
# categories_steam_achievements^2                     0.006340
# categories_shared/split_screen genres_simulation    0.006000
# categories_online_pvp categories_partial_contro...  0.005432
# genres_simulation^2                                 0.004845
# genres_simulation                                   0.004845
# categories_remote_play_together genres_simulation   0.004698
# genres_strategy                                     0.004464
# genres_strategy^2                                   0.004464
# genres_rpg genres_casual                            0.004121
# categories_partial_controller_support               0.003880
# categories_partial_controller_support^2             0.003880
# categories_remote_play_together genres_early_ac...  0.003419
# genres_rpg                                          0.003226
# genres_rpg^2                                        0.003226
# genres_adventure genres_indie                       0.003085
# categories_online_pvp categories_steam_cloud        0.002763
# categories_family_sharing categories_partial_co...  0.002668
# categories_multi-player genres_casual               0.002492
# categories_partial_controller_support categorie...  0.001930
# categories_steam_trading_cards genres_simulation    0.000545
# categories_steam_trading_cards genres_action        0.000336
# genres_casual                                       0.000290
# genres_casual^2                                     0.000290
# categories_full_controller_support categories_p...  0.000000
# categories_shared/split_screen genres_early_access -0.000056
# categories_full_controller_support categories_r... -0.000093
# categories_single-player genres_adventure          -0.000105
# categories_steam_achievements genres_simulation    -0.000203
# categories_online_pvp categories_remote_play_to... -0.000253
# genres_action genres_strategy                      -0.000853
# categories_online_pvp                              -0.001028
# categories_online_pvp^2                            -0.001028
# genres_simulation genres_strategy                  -0.001061
# categories_remote_play_together genres_rpg         -0.001065
# categories_steam_trading_cards categories_share... -0.001322
# categories_multi-player categories_online_pvp      -0.001440
# categories_partial_controller_support genres_si... -0.001494
# genres_action genres_early_access                  -0.001710
# categories_full_controller_support categories_s... -0.002052
# categories_family_sharing genres_adventure         -0.002420
# genres_simulation genres_early_access              -0.003062
# categories_single-player genres_action             -0.003617
# categories_steam_cloud genres_action               -0.003730
# categories_single-player genres_casual             -0.004002
# categories_partial_controller_support genres_ca... -0.004020
# categories_steam_trading_cards categories_parti... -0.004085
# categories_remote_play_together genres_adventure   -0.004363
# genres_adventure genres_early_access               -0.005188
# genres_adventure genres_simulation                 -0.005518
# categories_steam_cloud genres_early_access         -0.005680
# categories_partial_controller_support categorie... -0.005774
# categories_multi-player categories_family_sharing  -0.005846
# categories_remote_play_together genres_strategy    -0.006062
# categories_full_controller_support genres_early... -0.006141
# categories_family_sharing categories_shared/spl... -0.007485
# categories_multi-player genres_early_access        -0.007570
# categories_single-player categories_steam_tradi... -0.008209
# categories_full_controller_support genres_strategy -0.008298
# genres_simulation genres_casual                    -0.009426
# genres_rpg genres_strategy                         -0.009552
# categories_multi-player categories_shared/split... -0.009673
# categories_full_controller_support^2               -0.010218
# categories_full_controller_support                 -0.010218
# categories_online_pvp categories_family_sharing    -0.010949
# categories_shared/split_screen genres_rpg          -0.010986
# categories_steam_cloud genres_rpg                  -0.011282
# categories_partial_controller_support genres_ac... -0.011564
# categories_steam_achievements categories_steam_... -0.011835
# categories_steam_trading_cards genres_casual       -0.012580
# genres_action genres_simulation                    -0.012674
# categories_single-player genres_strategy           -0.012961
# categories_shared/split_screen                     -0.013008
# categories_shared/split_screen^2                   -0.013008
# categories_steam_trading_cards categories_steam... -0.014077
# categories_steam_achievements categories_family... -0.014267
# categories_full_controller_support genres_casual   -0.014381
# categories_steam_trading_cards genres_adventure    -0.014746
# categories_single-player categories_partial_con... -0.015123
# categories_online_pvp genres_early_access          -0.015243
# categories_single-player genres_rpg                -0.015323
# categories_shared/split_screen genres_action       -0.015547
# categories_remote_play_together genres_action      -0.016764
# categories_full_controller_support categories_f... -0.018162
# categories_online_pvp genres_indie                 -0.018201
# categories_online_pvp genres_simulation            -0.018510
# categories_family_sharing genres_action            -0.018689
# categories_online_pvp genres_strategy              -0.019106
# categories_partial_controller_support genres_indie -0.019834
# categories_single-player categories_family_sharing -0.020319
# genres_indie^2                                     -0.020642
# genres_indie                                       -0.020642
# categories_family_sharing genres_rpg               -0.020730
# categories_shared/split_screen genres_strategy     -0.021096
# categories_steam_cloud categories_remote_play_t... -0.021239
# genres_early_access                                -0.021409
# genres_early_access^2                              -0.021409
# categories_multi-player genres_indie               -0.021650
# categories_multi-player categories_steam_tradin... -0.022127
# categories_single-player genres_early_access       -0.022401
# categories_partial_controller_support genres_st... -0.022483
# categories_family_sharing genres_early_access      -0.022715
# categories_single-player genres_indie              -0.022744
# categories_single-player^2                         -0.023377
# categories_single-player                           -0.023377
# genres_strategy genres_casual                      -0.023654
# categories_multi-player categories_remote_play_... -0.024519
# categories_multi-player genres_action              -0.025559
# categories_online_pvp genres_casual                -0.025662
# categories_steam_achievements categories_remote... -0.025764
# genres_action genres_indie                         -0.026437
# categories_family_sharing genres_casual            -0.027121
# genres_adventure genres_strategy                   -0.027759
# categories_steam_achievements genres_adventure     -0.027911
# categories_multi-player genres_adventure           -0.028184
# categories_steam_cloud genres_casual               -0.028729
# genres_adventure genres_rpg                        -0.029107
# genres_early_access genres_casual                  -0.032592
# categories_online_pvp genres_adventure             -0.032901
# categories_steam_achievements genres_early_access  -0.033833
# categories_full_controller_support genres_indie    -0.034063
# categories_family_sharing genres_indie             -0.034703
# categories_steam_achievements genres_strategy      -0.038265
# categories_shared/split_screen genres_indie        -0.038862
# categories_steam_trading_cards genres_indie        -0.040429
# categories_shared/split_screen categories_remot... -0.042253
# genres_rpg genres_simulation                       -0.045399
# categories_steam_trading_cards categories_remot... -0.050774
# categories_steam_achievements genres_indie         -0.053563
# categories_steam_cloud genres_indie                -0.057242
# categories_steam_achievements genres_casual        -0.065116
# categories_family_sharing                          -0.073567
# categories_family_sharing^2                        -0.073567

# %%
best_price_features['catgen'] = list(catgen_ridge_results.index[np.abs(catgen_ridge_results['coef']) > .05])
best_price_features
# Out:
# {'main': [],
#  'catgen': ['categories_family_sharing',
#   'categories_single-player categories_multi-player',
#   'categories_full_controller_support categories_steam_achievements',
#   'categories_steam_trading_cards categories_remote_play_together',
#   'categories_steam_achievements categories_partial_controller_support',
#   'categories_steam_achievements genres_indie',
#   'categories_steam_achievements genres_casual',
#   'categories_steam_cloud genres_indie',
#   'categories_family_sharing^2',
#   'genres_indie genres_casual']}

# %%
## tags_num model
ridge_parameters = {'ridge__alpha': 10**np.linspace(-3, 3, 7)}

tags_num_grid_ridge = GridSearchCV(tags_num_ridge, ridge_parameters, cv = 5, scoring='r2', verbose=1)
tags_num_grid_ridge.fit(X_tags_num, y_train['price_log'])
tags_num_grid_ridge.score(X2_tags_num, y_test['price_log'])
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# 0.019960208859291506

# %%
tags_num_ridge_results = pd.DataFrame({'feature': tags_num_grid_ridge.feature_names_in_, 'coef': tags_num_grid_ridge.best_estimator_['ridge'].coef_}).set_index('feature')
tags_num_ridge_results.sort_values('coef', ascending=False)
# Out:
#                         coef
# feature
# Simulation          0.025140
# Singleplayer        0.021018
# Anime               0.020440
# Action              0.017363
# Open World          0.014581
# RPG                 0.013210
# Strategy            0.009891
# Multiplayer         0.008391
# Third Person        0.008107
# Story Rich          0.007886
# Action-Adventure    0.007498
# Atmospheric         0.006169
# Colorful            0.003167
# Adventure          -0.000170
# Funny              -0.000596
# Shooter            -0.000694
# Female Protagonist -0.001274
# 3D                 -0.001400
# Sci-fi             -0.002115
# Cute               -0.003037
# Exploration        -0.003492
# Sandbox            -0.003603
# Fantasy            -0.003673
# Casual             -0.010120
# Puzzle             -0.013713
# Pixel Graphics     -0.015404
# Early Access       -0.015459
# First-Person       -0.015776
# 2D                 -0.017770
# Indie              -0.025303

# %%
# Don't add anything from this model

# %%
## tags_bool model
ridge_parameters = {'ridge__alpha': 10**np.linspace(-3, 3, 7)}

tags_bool_grid_ridge = GridSearchCV(tags_bool_ridge, ridge_parameters, cv = 5, scoring='r2', verbose=1)
tags_bool_grid_ridge.fit(X_tags_bool, y_train['price_log'])
tags_bool_grid_ridge.score(X2_tags_bool, y_test['price_log'])
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# 0.10660713340922878

# %%
tags_bool_grid_results = pd.DataFrame({'feature': tags_bool_grid_ridge.feature_names_in_, 'coef': tags_bool_grid_ridge.best_estimator_['ridge'].coef_}).set_index('feature')
tags_bool_grid_results.sort_values('coef', ascending=False)
# Out:
#                         coef
# feature
# Anime               0.089530
# Multiplayer         0.088745
# Singleplayer        0.068367
# Simulation          0.058912
# Open World          0.052217
# Story Rich          0.040510
# Third Person        0.028491
# RPG                 0.020112
# Action              0.019720
# Strategy            0.015884
# Sandbox             0.013039
# Atmospheric         0.012920
# Sci-fi              0.011362
# Cute                0.008210
# Action-Adventure    0.004328
# Adventure           0.003691
# Exploration        -0.002152
# Female Protagonist -0.004222
# Colorful           -0.007152
# 3D                 -0.007475
# Shooter            -0.014491
# Fantasy            -0.018009
# Funny              -0.022753
# First-Person       -0.030294
# Casual             -0.051488
# Puzzle             -0.051582
# 2D                 -0.070206
# Pixel Graphics     -0.079026
# Early Access       -0.080395
# Indie              -0.109750

# %%
best_price_features['tags_bool'] = list(tags_bool_grid_results.index[np.abs(tags_bool_grid_results['coef']) > .05])
best_price_features
# Out:
# {'main': [],
#  'catgen': ['categories_family_sharing',
#   'categories_single-player categories_multi-player',
#   'categories_full_controller_support categories_steam_achievements',
#   'categories_steam_trading_cards categories_remote_play_together',
#   'categories_steam_achievements categories_partial_controller_support',
#   'categories_steam_achievements genres_indie',
#   'categories_steam_achievements genres_casual',
#   'categories_steam_cloud genres_indie',
#   'categories_family_sharing^2',
#   'genres_indie genres_casual'],
#  'tags_bool': ['Singleplayer',
#   'Indie',
#   'Casual',
#   'Simulation',
#   '2D',
#   'Early Access',
#   'Multiplayer',
#   'Anime',
#   'Puzzle',
#   'Open World',
#   'Pixel Graphics']}

# %%
# create a catgen df with polynomial features, to concatenate for main model
catgen_xform = pd.DataFrame(PolynomialFeatures(degree = 2, include_bias = False).fit_transform(catgen_df), columns=catgen_grid_ridge.best_estimator_.named_steps['poly'].get_feature_names_out(), index = catgen_df.index)

main_model_final = pd.concat([mainline_df[best_price_features['main']], catgen_xform[best_price_features['catgen']], tags_bool_df[best_price_features['tags_bool']]], axis = 1)
#pd.concat([X_main[best_price_features['main']], catgen_xform[best_price_features['catgen']], X_tags_bool[best_price_features['tags_bool']]], axis = 1)

main_colcheck = []
for temp_model_type in best_price_features.values():
    if isinstance(temp_model_type, list):
        for temp_colname in temp_model_type:
            main_colcheck.append(temp_colname in main_model_final.columns)
    else:
        main_colcheck.append(temp_model_type in main_model_final.columns)

all(main_colcheck)
# Out:
# True

# %% [markdown]
# #### <span style="color: Teal; font-weight: bold">Final Model</span>

# %% [markdown]
# After further consideration, I decided to create a model that included all features, and not just those that were the most predictive.

# %%
# create a catgen df with polynomial features, to concatenate for main model
catgen_xform = pd.DataFrame(PolynomialFeatures(degree = 2, include_bias = False).fit_transform(catgen_df), columns=catgen_grid_ridge.best_estimator_.named_steps['poly'].get_feature_names_out(), index = catgen_df.index)

main_model_final = pd.concat([mainline_df, catgen_xform, tags_bool_df], axis = 1)
#pd.concat([X_main[best_price_features['main']], catgen_xform[best_price_features['catgen']], X_tags_bool[best_price_features['tags_bool']]], axis = 1)

main_colcheck = []
for temp_model_type in best_price_features.values():
    if isinstance(temp_model_type, list):
        for temp_colname in temp_model_type:
            main_colcheck.append(temp_colname in main_model_final.columns)
    else:
        main_colcheck.append(temp_model_type in main_model_final.columns)

print(all(main_colcheck))
main_model_final.shape
# Out:
# True
# (15885, 243)

# %%
# run GridSearchCV for ridge model
X_ridge_final, X2_ridge_final, y_ridge_train, y_ridge_test = train_test_split(main_model_final, df['price_log'], test_size = 0.1, random_state = 42)

### pipeline: (1) polynomial transformation for catgen, (2) standard scaler for all, (3) ridge regression
main_final_ct = ColumnTransformer(
    transformers = [('std', StandardScaler(), X_ridge_final.columns)],
    remainder = 'passthrough')

main_final_pipe_ridge = Pipeline([('xform', main_final_ct), ('ridge', Ridge())])

ridge_parameters = {'ridge__alpha': 10**np.linspace(-3, 3, 7)}

main_final_grid_ridge = GridSearchCV(main_final_pipe_ridge, ridge_parameters, cv = 5, scoring='r2', verbose=1)
main_final_grid_ridge.fit(X_ridge_final, y_ridge_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('xform',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('std',
#                                                                          StandardScaler(),
#                                                                          Index(['website_bool', 'support_url_bool', 'supported_languages_int',
#        'full_audio_languages_int', 'categories_single-player',
#        'categories_multi-player', 'categories_online_pvp',
#        'categories_full_controller_support', 'categories_steam_trading_cards',
#        'categories_steam_achievements',
#        ...
#        'Puzzle', 'Female Protagonist', 'Open World', 'Sci-fi',
#        'Pixel Graphics', 'Funny', 'Action-Adventure', 'Shooter',
#        'Third Person', 'Sandbox'],
#       dtype='object', length=243))])),
#                                        ('ridge', Ridge())]),
#              param_grid={'ridge__alpha': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])},
#              scoring='r2', verbose=1)

# %%
main_final_ridge_rmse = np.sqrt(mean_squared_error(main_final_grid_ridge.predict(X2_ridge_final), y_ridge_test))
main_final_ridge_rmse_original = np.sqrt(mean_squared_error(np.log(main_final_grid_ridge.predict(X2_ridge_final)), np.log(y_ridge_test)))

print(f"RMSE: {main_final_ridge_rmse}\nRMSE in terms of original dollar price: ${round(main_final_ridge_rmse_original,4)}\nR^2 value: {main_final_grid_ridge.score(X2_ridge_final, y_ridge_test)}")
# Out:
# RMSE: 0.31300913845836426
# RMSE in terms of original dollar price: $0.1054
# R^2 value: 0.1598985950244467

# %%
ridge_best_params = pd.DataFrame({'features': main_final_grid_ridge.best_estimator_.feature_names_in_, 'coefficient': main_final_grid_ridge.best_estimator_.named_steps['ridge'].coef_})
ridge_best_params.set_index('features', inplace=True)
ridge_best_params['coefficient_absolute'] = np.abs(ridge_best_params.copy().coefficient)
ridge_best_params.sort_values('coefficient_absolute', ascending=False, inplace = True)
ridge_best_params.head(n=10)
# Out:
#                                              coefficient  coefficient_absolute
# features
# supported_languages_int                         0.029235              0.029235
# Anime                                           0.026571              0.026571
# 2D                                             -0.021930              0.021930
# categories_steam_cloud genres_indie            -0.021785              0.021785
# categories_steam_achievements genres_casual    -0.021700              0.021700
# Pixel Graphics                                 -0.021270              0.021270
# Puzzle                                         -0.019509              0.019509
# Singleplayer                                    0.019207              0.019207
# Indie                                          -0.019200              0.019200
# categories_steam_achievements genres_indie     -0.018067              0.018067

# %% [markdown]
# The top 5 predictive features are the number of text languages that are supported, whether a game has the Anime game tag, whether a game has the 2D name tag (negatively weighted), whether a game has both the 'steam cloud' category and 'indie' genre (interaction effect; negative weight), and whether a game has both the 'steam achievements' category and 'casual' genre (interaction effect; negative weight). However, the coefficients are of roughly the same magnitude.

# %%
plt.figure(figsize=(5, 5))
plt.plot(ridge_best_params['coefficient_absolute'], label = 'Ridge Regresion Coefficient (Absolute)')
#plt.plot(rfc_features['importance_cumulative'], label = 'Feature Importance (Cumulative)')
#plt.legend()
plt.xticks([])
plt.title('Ridge Regression Coefficient Sizes (Absolute values)')
plt.tight_layout()
plt.ylabel('Coefficient Size')

plt.show()

# %% [markdown]
# #### <span style="color: Teal; font-weight: bold">Summary</span>

# %% [markdown]
# The RMSE of this final model for predicting `price_log` is ~. The unit of `price_log` is the log of dollar price; converting the units to original dollar price, the model's RMSE corresponds to . This seems like a small margin of error given that the R^2 value for the model is only not bad, but not perfect at all.

# %%
# plot the model's residuals
main_final_ridge_resid = pd.DataFrame({'Actual': y_ridge_test, 'Predicted': main_final_grid_ridge.predict(X2_ridge_final), 'Residuals': y_ridge_test - main_final_grid_ridge.predict(X2_ridge_final)})

plt.figure(figsize = (6,4))
sns.scatterplot(x='Actual', y='Predicted', data=main_final_ridge_resid)
#plt.plot([2, 4], [-1, 1], color='red', linestyle='--')  # Line of perfect prediction
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Predicted vs Actual Prices')
plt.savefig('images/ridge_predicted_actual.png')
plt.show()

# Residual plot
plt.figure(figsize=(6,4))
sns.scatterplot(x='Actual', y='Residuals', data=main_final_ridge_resid)
plt.axhline(0, color='red', linestyle='--')  # Line at zero
plt.xlabel('Actual Price')
plt.ylabel('Residuals')
plt.title('Residuals vs Actual Prices')
plt.savefig('images/ridge_actual_residuals.png')
plt.show()

# %% [markdown]
# The model seems to essentially be guessing the mean; there's not enough variance in the predicted values.

# %% [markdown]
# The next step is to see if Dummy Regression produces similar results.

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Compare to Dummy Regression</span>

# %%
from sklearn.dummy import DummyRegressor
dummy_regressor_median = DummyRegressor(strategy="median")
dummy_regressor_median.fit(X_ridge_final, y_ridge_train)
y_pred_median = dummy_regressor_median.predict(X_ridge_final)

mse_median = mean_squared_error(y_ridge_train, y_pred_median)
r2_median = r2_score(y_ridge_train, y_pred_median)

print(f"RMSE (Median Strategy): {np.sqrt(mse_median)}")
print(f"R-squared (Median Strategy): {r2_median}")
# Out:
# RMSE (Median Strategy): 0.35811928387715597
# R-squared (Median Strategy): -0.04798896349391879

# %%
from sklearn.dummy import DummyRegressor
dummy_regressor_median = DummyRegressor(strategy="mean")
dummy_regressor_median.fit(X_ridge_final, y_ridge_train)
y_pred_median = dummy_regressor_median.predict(X_ridge_final)

mse_median = mean_squared_error(y_ridge_train, y_pred_median)
r2_median = r2_score(y_ridge_train, y_pred_median)

print(f"RMSE (Mean Strategy): {np.sqrt(mse_median)}")
print(f"R-squared (Mean Strategy): {r2_median}")
# Out:
# RMSE (Mean Strategy): 0.34982379983512907
# R-squared (Mean Strategy): 0.0

# %% [markdown]
# Interestingly, the RMSE for dummy regression is just a little higher than the ridge regression model's RMSE, but the R<sup>2</sup> is significantly lower (close to 0, while the real model's R<sup>2</sup> is almost 0.16).
#
# This suggests that the model is definitely finding some signal in the noise. Looking at further ML techniques to maximize finding the signal is warranted. The following techniques will be tried:
# -  Random Forest
# -  SVM
# -  (Possibly) DNNs

# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Further Modeling</span>

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Random Forest</span>
#
# See results from basic Random Forest, then use grid search methods and see if results improve.

# %%
from sklearn.ensemble import RandomForestRegressor

rfc = RandomForestRegressor(n_estimators=30, criterion = 'squared_error', max_depth = None, max_features=None, oob_score=True)
rfc.fit(X_ridge_final, y_ridge_train)

rfc.oob_score_
# Out:
# 0.1904525696595204

# %%
rfc.score(X2_ridge_final, y_ridge_test)
# Out:
# 0.2363257324040433

# %% [markdown]
# Use GridSearchCV to find best parameters. This will take a while, so save the results.

# %%
#rfc_params = {
#    'rfc__n_estimators': [50, 100, 200],
#    'rfc__max_depth': [None, 10, 20, 30],
#    'rfc__min_samples_split': [2, 5, 10],
#    'rfc__min_samples_leaf': [1, 2, 4]
#}

#rfc_pipe = Pipeline([('rfc', RandomForestRegressor(criterion='squared_error', oob_score=True))])
#rfc_grid = GridSearchCV(rfc_pipe, param_grid=rfc_params, scoring='r2', verbose = 2, cv = 5, n_jobs=-1)

#rfc_grid.fit(X_ridge_final, y_ridge_train)

# %%
## Save results
#import pickle

#with open('data/rfc_grid.pkl', 'wb') as file:
#    pickle.dump(rfc_grid, file)

# %%
import pickle
with open('data/rfc_grid.pkl', 'rb') as file:
    rfc_grid = pickle.load(file)

# %%
print(f"Best parameters found: {rfc_grid.best_params_}")
print(f"Best R^2 score: {rfc_grid.best_score_}")
print(f"Best model RMSE: {np.sqrt(mean_squared_error(rfc_grid.predict(X2_ridge_final), y_ridge_test))}")
# Out:
# Best parameters found: {'rfc__max_depth': 30, 'rfc__min_samples_leaf': 4, 'rfc__min_samples_split': 2, 'rfc__n_estimators': 200}
# Best R^2 score: 0.2617188086186317
# Best model RMSE: 0.29356929999922626

# %%
print(f"Best model R^2 dev score: {rfc_grid.best_estimator_.score(X2_ridge_final, y_ridge_test)}")
# Out:
# Best model R^2 dev score: 0.26100933694396

# %%
X_ridge_final.shape
# Out:
# (14296, 243)

# %% [markdown]
# Find the feature importance

# %%
rfc_features = pd.DataFrame({'features': rfc_grid.best_estimator_.feature_names_in_, 'importance': rfc_grid.best_estimator_.named_steps['rfc'].feature_importances_})
rfc_features.set_index('features', inplace=True)
rfc_features.sort_values('importance', ascending=False, inplace = True)
rfc_features['importance_cumulative'] = rfc_features.copy().importance.cumsum()
rfc_features.head(n=10)
# Out:
#                                         importance  importance_cumulative
# features
# categories_family_sharing genres_indie    0.109801               0.109801
# supported_languages_int                   0.098801               0.208602
# full_audio_languages_int                  0.075000               0.283602
# Anime                                     0.024918               0.308521
# website_bool                              0.023759               0.332280
# support_url_bool                          0.023585               0.355865
# Singleplayer                              0.017833               0.373698
# 2D                                        0.016776               0.390474
# Story Rich                                0.014289               0.404764
# 3D                                        0.013607               0.418371

# %%
print(f"Number of features that explain more than their equal proportion (1/243): {sum(rfc_features['importance']>1/243)}")
# Out:
# Number of features that explain more than their equal proportion (1/243): 48

# %%
rfc_features['importance'][0:48]
# Out:
# features
# categories_family_sharing genres_indie                       0.109801
# supported_languages_int                                      0.098801
# full_audio_languages_int                                     0.075000
# Anime                                                        0.024918
# website_bool                                                 0.023759
# support_url_bool                                             0.023585
# Singleplayer                                                 0.017833
# 2D                                                           0.016776
# Story Rich                                                   0.014289
# 3D                                                           0.013607
# Simulation                                                   0.012643
# Pixel Graphics                                               0.012436
# Puzzle                                                       0.012430
# Adventure                                                    0.011530
# Indie                                                        0.011385
# Multiplayer                                                  0.011372
# Casual                                                       0.011330
# Atmospheric                                                  0.011099
# Action                                                       0.010731
# Fantasy                                                      0.010398
# Exploration                                                  0.010347
# Open World                                                   0.010129
# Cute                                                         0.009735
# categories_multi-player categories_steam_cloud               0.009486
# categories_steam_achievements categories_steam_cloud         0.009351
# RPG                                                          0.009210
# categories_steam_achievements genres_casual                  0.008831
# First-Person                                                 0.008235
# Female Protagonist                                           0.008015
# Colorful                                                     0.007746
# Sci-fi                                                       0.007681
# genres_adventure genres_casual                               0.007236
# Third Person                                                 0.007109
# Strategy                                                     0.006926
# Shooter                                                      0.006628
# categories_family_sharing                                    0.006502
# categories_steam_cloud genres_adventure                      0.005999
# categories_family_sharing^2                                  0.005857
# Action-Adventure                                             0.005750
# Funny                                                        0.005743
# Sandbox                                                      0.005732
# Early Access                                                 0.005295
# categories_family_sharing genres_casual                      0.005126
# categories_multi-player categories_steam_achievements        0.005124
# categories_single-player genres_casual                       0.005023
# categories_steam_achievements genres_adventure               0.004599
# genres_action genres_adventure                               0.004440
# categories_full_controller_support categories_steam_cloud    0.004275
# Name: importance, dtype: float64

# %% [markdown]
# We can see that there are some features that are very important for predicting price. In particular, three features stand out: the interaction between 'family sharing' category and 'indie' genre, the number of supported text languages, and the number of supported audio languages. Together these account for roughly 28% of the model's predictive power.

# %%
plt.figure(figsize=(4, 4))
features_to_correlate = list(rfc_features.index[0:3])
sns.heatmap(np.round(pd.concat([X_ridge_final[features_to_correlate], y_ridge_train], axis = 1).corr(),3), cmap = 'coolwarm', annot = True, center = 0)
plt.title('Correlations of most important features with price_log')
plt.savefig('images/rfc_correlations.png')
plt.show()

# %% [markdown]
# From the above, we can see that the, of the most important features, only the interaction between the 'family sharing' category & 'indie' genre, and having the 2D tag, are negatively related to the price. The other features are positively related.

# %%
plt.figure(figsize = (5, 5))
plt.plot(rfc_features['importance'], label = 'Feature Importance')
plt.plot(rfc_features['importance_cumulative'], label = 'Feature Importance (Cumulative)')
plt.legend()
plt.xticks([])
plt.tight_layout()
plt.ylabel('Feature Importance')
plt.title('Random Forest Regressor Feature Importance Values')

plt.show()

# %%
# Plot the values again
rfc_resid = pd.DataFrame({'Actual': y_ridge_test, 'Predicted': rfc_grid.best_estimator_.predict(X2_ridge_final), 'Residuals': y_ridge_test - rfc_grid.best_estimator_.predict(X2_ridge_final)})

plt.figure(figsize = (6,4))
sns.scatterplot(x='Actual', y='Predicted', data=rfc_resid)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Predicted vs Actual Prices - Random Forest')
plt.savefig('images/rfc_predicted_actual.png')
plt.show()

# Residual plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Actual', y='Residuals', data=rfc_resid)
plt.axhline(0, color='red', linestyle='--')  # Line at zero
plt.xlabel('Actual Price')
plt.ylabel('Residuals')
plt.title('Residuals vs Actual Prices - Random Forest')
plt.savefig('images/rfc_actual_residuals.png')
plt.show()

# %% [markdown]
# Although the final results look a bit better than basic regression, there's still a significant lack of normality in the residuals.

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">SVM</span>

# %%
from sklearn.svm import SVR

svr_model = SVR(kernel='rbf', C=1.0, epsilon=0.1)
svr_model.fit(X_ridge_final, y_ridge_train)
# Out:
# SVR()

# %%
svr_pred = svr_model.predict(X2_ridge_final)
svr_rmse = np.sqrt(mean_squared_error(y_ridge_test, svr_pred))
svr_r2 = r2_score(y_ridge_test, svr_pred)

print(f"Root Mean Squared Error: {svr_rmse}")
print(f"R^2 Score: {svr_r2}")
# Out:
# Root Mean Squared Error: 0.30194883531651134
# R^2 Score: 0.21822029092699036

# %%
# GridSearch for SVR
#param_grid = {
#    'kernel': ['rbf', 'linear'],
#    'C': [0.1, 1, 10, 100],
#    'epsilon': [0.01, 0.1, 0.2, 0.5]
#}
#
#svr_grid = GridSearchCV(svr_model, param_grid, scoring='r2', n_jobs=-1, cv=5, verbose=2)
#svr_grid.fit(X_ridge_final, y_ridge_train)

# %%
## Save results
#with open('data/svr_grid.pkl', 'wb') as file:
#    pickle.dump(svr_grid_search, file)

# %%
with open('data/svr_grid.pkl', 'rb') as file:
    svr_grid = pickle.load(file)

# %%
svr_grid
# Out:
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'epsilon': [0.01, 0.1, 0.2, 0.5],
#                          'kernel': ['rbf', 'linear']},
#              scoring='r2', verbose=2)

# %%
svr_grid.score(X2_ridge_final, y_ridge_test)
# Out:
# 0.22461125003317284

# %%
svr_grid.best_params_
# Out:
# {'C': 1, 'epsilon': 0.2, 'kernel': 'rbf'}

# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Results</span>

# %%
feature_rank_ridge = ridge_best_params.copy()
feature_rank_ridge['rank_ridge'] = list(range(1, ridge_best_params.shape[0]+1))
feature_rank_ridge.head()
# Out:
#                                              coefficient  \
# features
# supported_languages_int                         0.029235
# Anime                                           0.026571
# 2D                                             -0.021930
# categories_steam_cloud genres_indie            -0.021785
# categories_steam_achievements genres_casual    -0.021700
#
#                                              coefficient_absolute  rank_ridge
# features
# supported_languages_int                                  0.029235           1
# Anime                                                    0.026571           2
# 2D                                                       0.021930           3
# categories_steam_cloud genres_indie                      0.021785           4
# categories_steam_achievements genres_casual              0.021700           5

# %%
feature_rank_rf = rfc_features.copy()
feature_rank_rf['rank_rf'] = list(range(1, feature_rank_rf.shape[0]+1))
feature_rank_rf.head()
# Out:
#                                         importance  importance_cumulative  \
# features
# categories_family_sharing genres_indie    0.109801               0.109801
# supported_languages_int                   0.098801               0.208602
# full_audio_languages_int                  0.075000               0.283602
# Anime                                     0.024918               0.308521
# website_bool                              0.023759               0.332280
#
#                                         rank_rf
# features
# categories_family_sharing genres_indie        1
# supported_languages_int                       2
# full_audio_languages_int                      3
# Anime                                         4
# website_bool                                  5

# %%
feature_rank_both = pd.concat([feature_rank_rf, feature_rank_ridge], axis = 1)
feature_rank_both['rank_wt_sum'] = feature_rank_both[['rank_ridge','rank_rf']]@np.array([0.5,1]) # get weighted sum, where ridge model worth 1/2 of rf model
feature_rank_both = feature_rank_both.sort_values('rank_wt_sum')
feature_rank_both.head(n=10)
# Out:
#                                         importance  importance_cumulative  \
# features
# supported_languages_int                   0.098801               0.208602
# Anime                                     0.024918               0.308521
# 2D                                        0.016776               0.390474
# Singleplayer                              0.017833               0.373698
# website_bool                              0.023759               0.332280
# full_audio_languages_int                  0.075000               0.283602
# Pixel Graphics                            0.012436               0.443450
# Puzzle                                    0.012430               0.455880
# categories_family_sharing genres_indie    0.109801               0.109801
# Indie                                     0.011385               0.478795
#
#                                         rank_rf  coefficient  \
# features
# supported_languages_int                       2     0.029235
# Anime                                         4     0.026571
# 2D                                            8    -0.021930
# Singleplayer                                  7     0.019207
# website_bool                                  5     0.016314
# full_audio_languages_int                      3     0.014426
# Pixel Graphics                               12    -0.021270
# Puzzle                                       13    -0.019509
# categories_family_sharing genres_indie        1    -0.010025
# Indie                                        15    -0.019200
#
#                                         coefficient_absolute  rank_ridge  \
# features
# supported_languages_int                             0.029235           1
# Anime                                               0.026571           2
# 2D                                                  0.021930           3
# Singleplayer                                        0.019207           8
# website_bool                                        0.016314          14
# full_audio_languages_int                            0.014426          21
# Pixel Graphics                                      0.021270           6
# Puzzle                                              0.019509           7
# categories_family_sharing genres_indie              0.010025          33
# Indie                                               0.019200           9
#
#                                         rank_wt_sum
# features
# supported_languages_int                         2.5
# Anime                                           5.0
# 2D                                              9.5
# Singleplayer                                   11.0
# website_bool                                   12.0
# full_audio_languages_int                       13.5
# Pixel Graphics                                 15.0
# Puzzle                                         16.5
# categories_family_sharing genres_indie         17.5
# Indie                                          19.5

# %%
# Create DataFrame to compare feature performance
both_model_features = pd.concat([rfc_features.copy().reset_index(), ridge_best_params.copy().reset_index()], axis = 1)
both_model_features.columns = ['rf_feature', 'rf_importance', 'rf_imp_cum', 'ridge_features', 'ridge_coefficient', 'ridge_coef_abs']
both_model_features.head(n=20)
# Out:
#                                 rf_feature  rf_importance  rf_imp_cum  \
# 0   categories_family_sharing genres_indie       0.109801    0.109801
# 1                  supported_languages_int       0.098801    0.208602
# 2                 full_audio_languages_int       0.075000    0.283602
# 3                                    Anime       0.024918    0.308521
# 4                             website_bool       0.023759    0.332280
# 5                         support_url_bool       0.023585    0.355865
# 6                             Singleplayer       0.017833    0.373698
# 7                                       2D       0.016776    0.390474
# 8                               Story Rich       0.014289    0.404764
# 9                                       3D       0.013607    0.418371
# 10                              Simulation       0.012643    0.431014
# 11                          Pixel Graphics       0.012436    0.443450
# 12                                  Puzzle       0.012430    0.455880
# 13                               Adventure       0.011530    0.467410
# 14                                   Indie       0.011385    0.478795
# 15                             Multiplayer       0.011372    0.490167
# 16                                  Casual       0.011330    0.501497
# 17                             Atmospheric       0.011099    0.512596
# 18                                  Action       0.010731    0.523327
# 19                                 Fantasy       0.010398    0.533725
#
#                                        ridge_features  ridge_coefficient  \
# 0                             supported_languages_int           0.029235
# 1                                               Anime           0.026571
# 2                                                  2D          -0.021930
# 3                 categories_steam_cloud genres_indie          -0.021785
# 4         categories_steam_achievements genres_casual          -0.021700
# 5                                      Pixel Graphics          -0.021270
# 6                                              Puzzle          -0.019509
# 7                                        Singleplayer           0.019207
# 8                                               Indie          -0.019200
# 9          categories_steam_achievements genres_indie          -0.018067
# 10                                                RPG           0.017154
# 11                          categories_family_sharing          -0.016417
# 12                        categories_family_sharing^2          -0.016417
# 13                                       website_bool           0.016314
# 14  categories_steam_trading_cards categories_remo...          -0.015688
# 15  categories_full_controller_support categories_...           0.015624
# 16            categories_steam_cloud genres_adventure           0.015298
# 17                         genres_indie genres_casual           0.015192
# 18                                         Simulation           0.015165
# 19  categories_steam_achievements categories_parti...           0.014555
#
#     ridge_coef_abs
# 0         0.029235
# 1         0.026571
# 2         0.021930
# 3         0.021785
# 4         0.021700
# 5         0.021270
# 6         0.019509
# 7         0.019207
# 8         0.019200
# 9         0.018067
# 10        0.017154
# 11        0.016417
# 12        0.016417
# 13        0.016314
# 14        0.015688
# 15        0.015624
# 16        0.015298
# 17        0.015192
# 18        0.015165
# 19        0.014555

# %% [markdown]
# FINAL TODO
#
# - EDA final presentation
# 	- Slides--reduce to 5 - 7 bullet points; top things discovered
# 	- Also look at producers, developers
# 	- Price
# 		- Identify outlier cutoff; use z-score method
# 		- Try log transformation, vs. sqrt
# 	- Focus on actionable insights
# 	- Include some relevant charts
# - Final presentation
# 	- README file
# 		- Can use slide deck to identify snapshots to share
