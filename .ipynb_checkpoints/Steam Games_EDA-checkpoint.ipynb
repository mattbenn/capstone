# %% [markdown]
# # <span style="color: Teal; font-weight: bold">What Drives the Prices of Video Games? (EDA)</span>

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold"> CRISP-DM Framework</span>
#
# <span style="color: Teal; text-decoration: underline">**Determine Business Objectives:**</span> Video games are now <a href="https://www.forbes.com/sites/forbesagencycouncil/2023/11/17/the-gaming-industry-a-behemoth-with-unprecedented-global-reach/">one of the largest enterainment industries in the world</a>, and Steam is one of the largest platforms for the distribution and hosting of personal computer (PC) games, and has been for <a href="https://archive.vn/JkIMI">over a decade</a>. Many video game developers release a variety of games on Steam of different genres, budgets, and quality, all tailored to different market segments. Developers have a strong interest in predicting how popular their games will be and which price points to choose when selling their games. Therefore, high-quality data showing what characteristics of games are related to popularity and price are of great interest (and great value) to video game developers looking to distribute games to a wide PC audience.
#
# <span style="color: Teal; text-decoration: underline">**Assess Situation:**</span> I am working with data from <a href="https://www.kaggle.com/datasets/artermiloff/steam-games-dataset/data">Kaggle</a>, scraped from the <a href="https://partner.steamgames.com/doc/sdk/api">Steamworks API</a>, containing data on video games sold on the Steam storefront. The data is up to date as of May 2024, which is recent enough to be relevant to developers currently forming/refining business strategies in their development and distribution of their games. The dataset contains data for games released many years ago but the price points given are those that are current as of May 2024, so some care will need to be taken regarding the release window of games--the price of games tend to go down within a year after their release and may steadily decrease in price after that. There are many features that consisting JSON-formatted strings holding multiple pieces of information (e.g., metadata tags, game genre, etc.), and these will have to be dealt with on a case-by-case basis, with decisions made about how to use this data to predict game price.
#
# The main benefit from this analysis will be identifying the core characteristics of games that are associated with higher prices, but this data will not be able to show causal relationships. Foe example, it may be the case that games of a certain genre (e.g., first-person shooters) sell for more on average, and an economist may conclude that the high price is due to high demand. However, it may be the case that they sell for more because they are inherently more expensive to make and maintain, and so price points are higher for games of this genre. Furthermore, it may be the case that most games in this genre do not sell enough copies to recoup their expensive production and advertising costs. Identifying factors that predict both price and popularity will help to ameliorate this and similar questions, but because the data is cross-sectional and there are many considerations that go into how profitable a game will be beyond popularity and price, care should be taken in the interpretation of findings to ensure that the analysis is used to wisely influence business strategies.
#
# There is also the issue that "popularity" is a more complex construct to define than "price". Many games have online services that must be maintained, which must be factored into costs. The simple metric of "number of copies sold" may be adequate to help gauge the profitability of simple games that require no ongoing maintenance or services, but may not be enough to predict profitability for games that have both ongoing services and ongoing subscriptions and add-on purchases that serve as extra revenue streams for the seller. This issue will be discussed in more detail later.
#
# <span style="color: Teal; text-decoration: underline">**Data Mining Goals:**</span> The goal of this project will be to identify the multivariate relationships in the data that predict (A) price point of games and (B) game popularity. The project will be deemed a success if one (or more) models can be built predicting the targets significantly above baseline and results in tangible advice that businesses could use to improve their business strategy.
#
# <span style="color: Teal; text-decoration: underline">**Project Plan:**</span> The data has already been scarped from the internet, and only exploratory data analysis, data cleaning, and data modeling are left. The project will consist of the aforementioned data preprocessing and data processing steps, as well as writing a summary of findings.

# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Setup & Data Import</span>

# %%
# Python library import block
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
import seaborn as sns
import matplotlib.pyplot as plt
import ast

from sklearn.metrics import mean_squared_error

# Custom functions from module
from extra_functions import cprint # colored print; makes some output a bit easier to read
from extra_functions import plotColumnCounts # bar plots (categorical) or histograms (numerical) for columns
from extra_functions import trim_feature # remove categories from a model if the total proportion represented is under a certain threshold (default: 1%)
from extra_functions import convert_range_to_avg

# %%
## Import data
# (To allow upload to GitHub, I reduced the size of the original dataset, removing observations that would be removed during analysis anyway)
#df = pd.read_csv("data/games_may2024_cleaned.csv")
df = pd.read_csv('data/games_may2024_cleaned_over_5_dollars.zip', compression = 'zip')
df.head()
# Out:
#    Unnamed: 0   AppID                             name release_date  \
# 0           4  359550  Tom Clancy's Rainbow Six® Siege   2015-12-01
# 1           6  105600                         Terraria   2011-05-16
# 2           7    4000                      Garry's Mod   2006-11-29
# 3           8  252490                             Rust   2018-02-08
# 4          10  292030        The Witcher® 3: Wild Hunt   2015-05-18
#
#    required_age  price  dlc_count  \
# 0            17  19.99          9
# 1             0   9.99          2
# 2             0   9.99          0
# 3            17  39.99          4
# 4             0   9.99         22
#
#                                 detailed_description  \
# 0  Edition Comparison Ultimate Edition The Tom Cl...
# 1  Dig, Fight, Explore, Build: The very world is ...
# 2  Garry's Mod is a physics sandbox. There aren't...
# 3  The only aim in Rust is to survive. Everything...
# 4  Special Offer About the Game THE MOST AWARDED ...
#
#                                       about_the_game  \
# 0  “One of the best first-person shooters ever ma...
# 1  Dig, Fight, Explore, Build: The very world is ...
# 2  Garry's Mod is a physics sandbox. There aren't...
# 3  The only aim in Rust is to survive. Everything...
# 4  THE MOST AWARDED GAME OF A GENERATION NOW ENHA...
#
#                                    short_description  ...  \
# 0  Tom Clancy's Rainbow Six® Siege is an elite, t...  ...
# 1  Dig, fight, explore, build! Nothing is impossi...  ...
# 2  Garry's Mod is a physics sandbox. There aren't...  ...
# 3  The only aim in Rust is to survive. Everything...  ...
# 4  You are Geralt of Rivia, mercenary monster sla...  ...
#
#   average_playtime_forever average_playtime_2weeks median_playtime_forever  \
# 0                    16213                     578                    3016
# 1                     7451                     548                    2110
# 2                    15387                     359                    1587
# 3                    16499                    1486                    2513
# 4                     3748                     488                     818
#
#   median_playtime_2weeks peak_ccu  \
# 0                    331    68162
# 1                    180    23331
# 2                    106    21459
# 3                    633   122371
# 4                    117    13475
#
#                                                 tags  pct_pos_total  \
# 0  {'FPS': 9689, 'PvP': 9073, 'e-sports': 9026, '...             85
# 1  {'Open World Survival Craft': 15938, 'Sandbox'...             97
# 2  {'Sandbox': 18400, 'Moddable': 14269, 'Multipl...             96
# 3  {'Survival': 17867, 'Crafting': 11333, 'Multip...             87
# 4  {'Open World': 12344, 'RPG': 10502, 'Story Ric...             96
#
#    num_reviews_total  pct_pos_recent num_reviews_recent
# 0            1091695              77              10566
# 1            1026239              96               8931
# 2             918752              96               7053
# 3             874762              86               9347
# 4             707825              95               4162
#
# [5 rows x 47 columns]

# %%
print(f"Shape: {df.shape}")
df.info()
# Out:
# Shape: (34448, 47)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34448 entries, 0 to 34447
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                34448 non-null  int64
#  1   AppID                     34448 non-null  int64
#  2   name                      34447 non-null  object
#  3   release_date              34448 non-null  object
#  4   required_age              34448 non-null  int64
#  5   price                     34448 non-null  float64
#  6   dlc_count                 34448 non-null  int64
#  7   detailed_description      34411 non-null  object
#  8   about_the_game            34396 non-null  object
#  9   short_description         34441 non-null  object
#  10  reviews                   6195 non-null   object
#  11  header_image              34448 non-null  object
#  12  website                   20124 non-null  object
#  13  support_url               20049 non-null  object
#  14  support_email             29068 non-null  object
#  15  windows                   34448 non-null  bool
#  16  mac                       34448 non-null  bool
#  17  linux                     34448 non-null  bool
#  18  metacritic_score          34448 non-null  int64
#  19  metacritic_url            3087 non-null   object
#  20  achievements              34448 non-null  int64
#  21  recommendations           34448 non-null  int64
#  22  notes                     6589 non-null   object
#  23  supported_languages       34448 non-null  object
#  24  full_audio_languages      34448 non-null  object
#  25  packages                  34448 non-null  object
#  26  developers                34448 non-null  object
#  27  publishers                34448 non-null  object
#  28  categories                34448 non-null  object
#  29  genres                    34448 non-null  object
#  30  screenshots               34448 non-null  object
#  31  movies                    34448 non-null  object
#  32  user_score                34448 non-null  int64
#  33  score_rank                11 non-null     float64
#  34  positive                  34448 non-null  int64
#  35  negative                  34448 non-null  int64
#  36  estimated_owners          34448 non-null  object
#  37  average_playtime_forever  34448 non-null  int64
#  38  average_playtime_2weeks   34448 non-null  int64
#  39  median_playtime_forever   34448 non-null  int64
#  40  median_playtime_2weeks    34448 non-null  int64
#  41  peak_ccu                  34448 non-null  int64
#  42  tags                      34448 non-null  object
#  43  pct_pos_total             34448 non-null  int64
#  44  num_reviews_total         34448 non-null  int64
#  45  pct_pos_recent            34448 non-null  int64
#  46  num_reviews_recent        34448 non-null  int64
# dtypes: bool(3), float64(2), int64(19), object(23)
# memory usage: 11.7+ MB

# %%
print(f"Duplicated rows: {sum(df.duplicated())}")
df.isna().sum()
# Out:
# Duplicated rows: 0
# Unnamed: 0                      0
# AppID                           0
# name                            1
# release_date                    0
# required_age                    0
# price                           0
# dlc_count                       0
# detailed_description           37
# about_the_game                 52
# short_description               7
# reviews                     28253
# header_image                    0
# website                     14324
# support_url                 14399
# support_email                5380
# windows                         0
# mac                             0
# linux                           0
# metacritic_score                0
# metacritic_url              31361
# achievements                    0
# recommendations                 0
# notes                       27859
# supported_languages             0
# full_audio_languages            0
# packages                        0
# developers                      0
# publishers                      0
# categories                      0
# genres                          0
# screenshots                     0
# movies                          0
# user_score                      0
# score_rank                  34437
# positive                        0
# negative                        0
# estimated_owners                0
# average_playtime_forever        0
# average_playtime_2weeks         0
# median_playtime_forever         0
# median_playtime_2weeks          0
# peak_ccu                        0
# tags                            0
# pct_pos_total                   0
# num_reviews_total               0
# pct_pos_recent                  0
# num_reviews_recent              0
# dtype: int64

# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Define Targets</span>
#
# Because there are so many features, and many features are redundant, missing a lot of data, or have unique data types (e.g., `tags`, which has a JSON-like structure although it's technically object type), I inspected the data manually. At this time, because of how the data is structured, it does not make sense to run a correlation analysis--this will be done later.
#
# The following sections followed that initial manual analysis and identify the targets I will use for the analysis.

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Popularity</span>

# %% [markdown]
# Price will be easy to define, but 'popularity' will require some more thinking. There are a few features that get at popularity:
# - metacritic_score, which is an aggregate sum of ratings from major games journals
# - recommendations, which are one form of community scoring.  However, this should be interpreted as a function of how many people purchased total (i.e., estimated ownership)
# - playtime metrics (average_playtime_forever, median_playtime_forever, average_playtime_2wks, and median_playtime_2wks); however, these don't seem to have values for all games when they should
# - peak_ccu, or peak concurrent current users
# - number of reviews (num_reviews_total and num_reviews_recent). This shold be interpreted in relation to estimated total owners
# - review scores; the most useful will be pct_pos_total and pct_pos_recent, since these capture information from other features already. These should be interpreted in light of total number of reviews.

# %%
# check playtime metrics
df.average_playtime_forever.quantile([i/10 for i in range(1, 10)])
# Out:
# 0.1      0.0
# 0.2      0.0
# 0.3      0.0
# 0.4      0.0
# 0.5      0.0
# 0.6      0.0
# 0.7      0.0
# 0.8      0.0
# 0.9    195.0
# Name: average_playtime_forever, dtype: float64

# %% [markdown]
# (Remove the playtime features; not enough data to be useful)

# %%
# check estimated_owners
df.estimated_owners.value_counts().sort_values()
# Out:
# estimated_owners
# 50000000 - 100000000        4
# 20000000 - 50000000        13
# 10000000 - 20000000        25
# 5000000 - 10000000         76
# 2000000 - 5000000         249
# 0 - 0                     274
# 1000000 - 2000000         408
# 500000 - 1000000          704
# 200000 - 500000          1428
# 100000 - 200000          1577
# 50000 - 100000           2201
# 20000 - 50000            4255
# 0 - 20000               23234
# Name: count, dtype: int64

# %% [markdown]
# 14 different ranges (excepting '0 - 0'); the range is consistently increasing, and the minimum for the next bin is either 2x or 2.5x the minimum of the previous bin.
#
# For estimated_owners, I could take the average of the range, or the range's minimum or maximum

# %% [markdown]
# Given this, it makes sense to use a single statistic each for professional reviews, number of copies sold, and user reviews.
#
# I will focus on games with listed prices between \\$10 and \\$100, to focus on games that are not free-to-play or advertisement-based and to avoid overpriced outliers (e.g., gimmick VR games).
#
# Below, I will explore possible target variables within this price range to identify feasible variables.

# %%
mainline_df = df.copy()[(df.price > 10) & (df.price < 100)]
mainline_df['release_year'] = pd.to_datetime(mainline_df.copy().release_date)
print(mainline_df.shape[0])

mainline_df.price.hist()
plt.title("Mainline games - price")
plt.show()

mainline_df[mainline_df.num_reviews_total > 0].pct_pos_total.hist()
plt.title('Mainline games - Pos total reviews | has any reviews')
plt.show()


mainline_df.release_year.hist()
plt.title('Mainline games - Release year')
plt.show()
# Out:
# 16380

# %%
genre_list_dict = {}

for genre_list in mainline_df['genres']:
#for genre_list in df[df.price == 0]['genres']:
    genre_list = ast.literal_eval(genre_list)
    for genre in genre_list:
        if(genre not in genre_list_dict.keys()):
            genre_list_dict[genre] = 0
        genre_list_dict[genre] += 1

#for item in genre_list_dict.items():
#    print(item)
genre_df = pd.DataFrame({'Genre': genre_list_dict.keys(), 'Count': genre_list_dict.values()})
genre_df.sort_values('Count', ascending=False)
# Out:
#                     Genre  Count
# 2                   Indie   9820
# 1               Adventure   7444
# 0                  Action   6912
# 9                  Casual   4419
# 5              Simulation   4347
# 4                     RPG   4055
# 7                Strategy   3670
# 6            Early Access   2483
# 10                 Sports    958
# 8                  Racing    621
# 3   Massively Multiplayer    304
# 16              Utilities    213
# 22  Design & Illustration    181
# 21   Animation & Modeling    131
# 23              Education    120
# 20       Game Development    103
# 18       Video Production     95
# 19      Software Training     83
# 17       Audio Production     75
# 12                Violent     60
# 24          Photo Editing     50
# 26         Web Publishing     42
# 13                   Gore     41
# 11                 Nudity     14
# 14         Sexual Content     13
# 15           Free to Play      9
# 25             Accounting      7

# %%
mainline_df[mainline_df.tags.str.contains('Singleplayer')].tags[0:5]
# Out:
# AppID
# 1091500    {'Cyberpunk': 6103, 'Open World': 5474, 'Nudit...
# 553850     {'Online Co-Op': 609, 'Third-Person Shooter': ...
# 1245620    {'Souls-like': 6048, 'Dark Fantasy': 4391, 'Op...
# 413150     {'Farming Sim': 7032, 'Pixel Graphics': 6609, ...
# 739630     {'Horror': 3754, 'Online Co-Op': 2462, 'Multip...
# Name: tags, dtype: object

# %%
tags_list_dict = {'Total': 0}

# Iterate over each row in the 'tags' column
for tags_dict in mainline_df.tags:
    tags_list_dict['Total'] += 1
    # Update the set with keys from the current dict
    tags_dict = ast.literal_eval(tags_dict)
    if not isinstance(tags_dict, dict):
        continue
    for temp_key in tags_dict:
        if temp_key not in tags_list_dict.keys():
            tags_list_dict[temp_key] = 0
        tags_list_dict[temp_key] += 1#tags_dict[temp_key]

# Convert the set to a list if needed
#unique_tags = list(unique_tags)#.sort()

# Save the unique tags for viewing
pd.DataFrame(tags_list_dict, index = ['Count']).T.sort_values('Count',ascending = False).head()
# Out:
#               Count
# Total         16318
# Singleplayer   9800
# Adventure      7207
# Indie          7127
# Action         6808

# %%
pd.DataFrame(tags_list_dict, index = ['Count']).T.sort_index().head()
# Out:
#             Count
# 1980s         238
# 1990's        447
# 2.5D          453
# 2D           3841
# 2D Fighter    222

# %% [markdown]
# I'll go with examining the 'mainline games', with prices between \\$10 and \\$100.

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Metacritic Scores</span>
#
# Below: Examine distribution of metacritic scores

# %%
mainline_df.metacritic_score.hist()
# Out:
# <Axes: >

# %%
print(f"Has metacritic: {sum(mainline_df.metacritic_score > 0)} | No metacritic: {sum(mainline_df.metacritic_score == 0)}")
# Out:
# Has metacritic: 2082 | No metacritic: 14298

# %%
print(f"Metacritic present proportion: {2082/(14298+2082)}")
# Out:
# Metacritic present proportion: 0.1271062271062271

# %% [markdown]
# Still a lot of games with price close to 0 dollars. metacritic_score will be an unbalanced class, but will still be useful to try to predict since this is a unique factor of video game success that no other features capture.

# %%
# look at estimated_owners by price, to get a sense of distribution
# get average of range
temp_df = mainline_df.copy()[['price']]
temp_df['estimated_owners'] = mainline_df.copy()['estimated_owners'].apply(convert_range_to_avg)

temp_df.plot(kind = 'scatter', x = 'estimated_owners', y = 'price', alpha = 0.2)
plt.xticks(rotation=90)
plt.show()

# %%
mainline_df.estimated_owners.value_counts(normalize=True)
# Out:
# estimated_owners
# 0 - 20000               0.607570
# 20000 - 50000           0.123504
# 50000 - 100000          0.075458
# 200000 - 500000         0.058791
# 100000 - 200000         0.058486
# 500000 - 1000000        0.032540
# 1000000 - 2000000       0.020208
# 2000000 - 5000000       0.013065
# 0 - 0                   0.004945
# 5000000 - 10000000      0.003602
# 10000000 - 20000000     0.001099
# 20000000 - 50000000     0.000549
# 50000000 - 100000000    0.000183
# Name: proportion, dtype: float64

# %% [markdown]
# Use estimated_owners, but trichotomize into three categories (or two): 0 - 20k, 20k-50k, >50k.
#
# Below: Check out user revies

# %%
# check out recommendations & pct_pos_total/pct_pos_recent
mainline_df.recommendations.hist()
plt.title('All recommendations')
plt.show()

# %%
mainline_df.recommendations[(mainline_df.recommendations < 5000)].hist()
plt.title('All recommendations < 5000')
plt.show()

# %%
mainline_df.recommendations.quantile([i/100 for i in range(1, 101, 3)])
# Out:
# 0.01          0.00
# 0.04          0.00
# 0.07          0.00
# 0.10          0.00
# 0.13          0.00
# 0.16          0.00
# 0.19          0.00
# 0.22          0.00
# 0.25          0.00
# 0.28          0.00
# 0.31          0.00
# 0.34          0.00
# 0.37          0.00
# 0.40          0.00
# 0.43          0.00
# 0.46          0.00
# 0.49          0.00
# 0.52          0.00
# 0.55          0.00
# 0.58        122.00
# 0.61        153.00
# 0.64        194.00
# 0.67        248.00
# 0.70        317.00
# 0.73        415.00
# 0.76        557.00
# 0.79        758.00
# 0.82       1073.00
# 0.85       1546.30
# 0.88       2295.56
# 0.91       3712.23
# 0.94       7171.30
# 0.97      17462.09
# 1.00    1088708.00
# Name: recommendations, dtype: float64

# %% [markdown]
# Over half of the dataset has no recommendations, and very positively skewed (one game has  ~100x more recommendations than even 97th percentile)
# Still, may be useful--half the dataset does have recommendations.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'AppID', 'name', 'release_date', 'required_age', 'price',
#        'dlc_count', 'detailed_description', 'about_the_game',
#        'short_description', 'reviews', 'header_image', 'website',
#        'support_url', 'support_email', 'windows', 'mac', 'linux',
#        'metacritic_score', 'metacritic_url', 'achievements', 'recommendations',
#        'notes', 'supported_languages', 'full_audio_languages', 'packages',
#        'developers', 'publishers', 'categories', 'genres', 'screenshots',
#        'movies', 'user_score', 'score_rank', 'positive', 'negative',
#        'estimated_owners', 'average_playtime_forever',
#        'average_playtime_2weeks', 'median_playtime_forever',
#        'median_playtime_2weeks', 'peak_ccu', 'tags', 'pct_pos_total',
#        'num_reviews_total', 'pct_pos_recent', 'num_reviews_recent'],
#       dtype='object')

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Summary</span>
#
# **Target features:**
# - Professional reviews: metacritic_score Use a two-part model to predict (A) a non-zero outcome (a classification model), and (B) the value of the recommendations for the non-zero outcome
# - Number of copies sold: estimated_owners (transform to have three values, '0 - 20k', '20k - 50k', and '>50k' and use logistic multinomial regression)
# - User reviews: recommendations. Use a two-part model to predict (A) a non-zero outcome (a classification model), and (B) the value of the recommendations for the non-zero outcome
#
# **Features to remove:**
# - average_playtime_forever, average_playtime_2weeks, median_playtime_forever, median_playtime_2weeks

# %%
target_features = ['metacritic_score', 'estimated_owners', 'recommendations']
target_transformation = {
    'two_stage_model_features': ['metacritic_score', 'recommendations'],
    'polychotomize_features': target_features[1]
}

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Price</span>

# %%
print(f"Price == 0: {sum(df.price == 0)} || 0 < Price < 10: {sum((df.price > 0) & (df.price < 10))} || Price >= 10: {sum(df.price >= 10)}")
# Out:
# Price == 0: 0 || 0 < Price < 10: 17911 || Price >= 10: 16537

# %%
mainline_df.price.hist()
plt.title('10 < Price < 100')
plt.show()

# %%
np.sqrt(mainline_df.price).hist()
# Out:
# <Axes: >

# %%
target_features.append('price')
target_transformation['square_root'] = 'price'

# %%
print(target_features)
print(target_transformation)
# Out:
# ['metacritic_score', 'estimated_owners', 'recommendations', 'price']
# {'two_stage_model_features': ['metacritic_score', 'recommendations'], 'polychotomize_features': 'estimated_owners', 'square_root': 'price'}

# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Preprocessing</span>

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Preprocessing -- Targets</span>
# Re-create dataframe to work with (`mainline_df`) as well as remove any observations in the '0 - 0' `estimated_owners` feature group.

# %%
mainline_df = df.copy()[(df.price >= 10) & (df.price <= 100) & (df.estimated_owners != '0 - 0')]
print(mainline_df.shape[0])
mainline_df.price.hist()
plt.title('Final Mainline Dataset - Price Hist')
plt.show()
# Out:
# 16318

# %%
target_transformation
# Out:
# {'two_stage_model_features': ['metacritic_score', 'recommendations'],
#  'polychotomize_features': 'estimated_owners',
#  'square_root': 'price'}

# %% [markdown]
# ### Two-stage model features
# Create Boolean features to mark the presence of a score

# %%
mainline_df['metacritic_bool'] = np.where(mainline_df.metacritic_score > 0, 1, 0)
mainline_df['metacritic_bool'].value_counts(normalize = True)
# Out:
# metacritic_bool
# 0    0.872595
# 1    0.127405
# Name: proportion, dtype: float64

# %%
mainline_df['recommendations_bool'] = np.where(mainline_df.recommendations > 0, 1, 0)
mainline_df['recommendations_bool'].value_counts(normalize = True)
# Out:
# recommendations_bool
# 0    0.550435
# 1    0.449565
# Name: proportion, dtype: float64

# %%
target_features.append('metacritic_bool')
target_features.append('recommendations_bool')

# %% [markdown]
# ### Polychotomize features
# Transform into a trichotomized feature

# %%
mainline_df.estimated_owners.value_counts()
# Out:
# estimated_owners
# 0 - 20000               9968
# 20000 - 50000           2023
# 50000 - 100000          1237
# 200000 - 500000          963
# 100000 - 200000          960
# 500000 - 1000000         533
# 1000000 - 2000000        331
# 2000000 - 5000000        214
# 5000000 - 10000000        59
# 10000000 - 20000000       18
# 20000000 - 50000000        9
# 50000000 - 100000000       3
# Name: count, dtype: int64

# %%
def categorize_owners(value):
    if value == '0 - 20000':
        return 0
    elif value == '20000 - 50000':
        return 1
    else:
        return 2

mainline_df['estimated_owners_tri'] = mainline_df.copy()['estimated_owners'].apply(categorize_owners)

mainline_df['estimated_owners_tri'].value_counts().sort_index()
# Out:
# estimated_owners_tri
# 0    9968
# 1    2023
# 2    4327
# Name: count, dtype: int64

# %%
target_features.append('estimated_owners_tri')

# %% [markdown]
# ### Square root price
# Find the square root of the price

# %%
mainline_df['price_sqrt'] = np.sqrt(mainline_df.copy()['price'])
mainline_df['price_sqrt'].hist()
# Out:
# <Axes: >

# %%
target_features.append('price_sqrt')

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Final Target Features list

# %%
target_features.remove('price')
target_features.remove('estimated_owners')
target_features.remove('recommendations')

# %%
mainline_df[target_features].head()
# Out:
#    metacritic_score  metacritic_bool  recommendations_bool  \
# 0                 0                0                     1
# 3                69                1                     1
# 5                86                1                     1
# 7                 0                0                     1
# 8                94                1                     1
#
#    estimated_owners_tri  price_sqrt
# 0                     2    4.471018
# 3                     2    6.323765
# 5                     2    5.476313
# 7                     2    6.323765
# 8                     2    7.745321

# %%
plotColumnCounts(mainline_df, target_features, number_graphs_per_row = 3, outlier_mask = False, stitle = 'Target Feature Plots', dropna = True, auto_show = True)

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Preprocessing -- Predictors</span>
# Identify columns to preprocess, then preprocess

# %%
# Create list for holding all model DataFrames
model_df_list = {'main': mainline_df}

# %%
## preprocess group descriptions
# descriptions - descriptive text of some kind, which may be useful to process with NLU
# to_drop - drop these from DataFrame entirely
# to_make_boolean - turn these into Boolean, with True representing the presence of a value and False otherwise
# to_make_integer - turn these into integer, with count of values from list-like object
# list_like - values are list-like objects; need to specially preprocess
# JSON_like - JSON-like structure; need to specially preprocess

pp_predictors_all = {'descriptions': ['about_the_game', 'short_description', 'reviews', 'notes'],
                     'to_drop': ['header_image', 'metacritic_url', 'user_score', 'score_rank', 'average_playtime_forever', 'median_playtime_forever', 'average_playtime_2weeks', 'median_playtime_2weeks'],
                     'to_make_boolean': ['website', 'support_url', 'support_email', 'screenshots', 'movies'],
                     'to_make_integer': ['supported_languages', 'full_audio_languages'],
                     'list_like': ['developers', 'publishers', 'categories', 'genres'],
                     'JSON_like': ['tags']
                     }

# double check all columns spelled correctly
all_inside = {}
all_inside_list = []

# make sure spellings are correct
for temp_listname, temp_list in pp_predictors_all.items():
    all_inside[temp_listname] = {}
    for temp_colname in temp_list:
        all_inside_list.append(temp_colname in df.columns)
        all_inside[temp_listname][temp_colname] = temp_colname in df.columns

all(all_inside_list)
# Out:
# True

# %% [markdown]
# **Special Cases & Notes**:
# - `supported_languages` and `full_audio_languages` -- list-like entries, but many in `full_audio_languages` are empty lists, and number of entries may matter. Get a list of languages as well as count of how many languages
# - `pct_pos_total` is percent positive revivews "total"; `pct_pos_recent` is percent positive reviews "recently"
#
# **Preprocessing Notes**:
# Features need to be separated into preprocessing categories, depending on needs of columns. These include:
# - OHE: Low-count categories can be put into this
# - TargetEncoding: High-count categories can be put into this
# - NLU: Text data that may benefit from natural language preprocessing can be put here. *(To be put aside in another DataFrame for now, to see if a separate model can be built with this data.)*

# %%
# create list for predictors to include in main model (not including genre or tags)
main_model_predictors = []

# %%
# Can AppID be used as an index?
mainline_df.AppID.nunique() == mainline_df.shape[0]
# Out:
# True

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Drop</span>
# Drop Columns and make AppID the index

# %%
mainline_df = mainline_df.drop(pp_predictors_all['to_drop'], axis = 1).set_index('AppID')

# %%
print(mainline_df.columns)
mainline_df.head()
# Out:
# Index(['Unnamed: 0', 'name', 'release_date', 'required_age', 'price',
#        'dlc_count', 'detailed_description', 'about_the_game',
#        'short_description', 'reviews', 'website', 'support_url',
#        'support_email', 'windows', 'mac', 'linux', 'metacritic_score',
#        'achievements', 'recommendations', 'notes', 'supported_languages',
#        'full_audio_languages', 'packages', 'developers', 'publishers',
#        'categories', 'genres', 'screenshots', 'movies', 'positive', 'negative',
#        'estimated_owners', 'peak_ccu', 'tags', 'pct_pos_total',
#        'num_reviews_total', 'pct_pos_recent', 'num_reviews_recent',
#        'metacritic_bool', 'recommendations_bool', 'estimated_owners_tri',
#        'price_sqrt'],
#       dtype='object')
#          Unnamed: 0                             name release_date  \
# AppID
# 359550            4  Tom Clancy's Rainbow Six® Siege   2015-12-01
# 252490            8                             Rust   2018-02-08
# 1091500          11                   Cyberpunk 2077   2020-12-09
# 553850           13                    HELLDIVERS™ 2   2024-02-08
# 1245620          14                       ELDEN RING   2022-02-24
#
#          required_age  price  dlc_count  \
# AppID
# 359550             17  19.99          9
# 252490             17  39.99          4
# 1091500            17  29.99          3
# 553850             17  39.99          0
# 1245620            16  59.99          2
#
#                                       detailed_description  \
# AppID
# 359550   Edition Comparison Ultimate Edition The Tom Cl...
# 252490   The only aim in Rust is to survive. Everything...
# 1091500  Cyberpunk 2077: Ultimate Edition Check out oth...
# 553850   Digital Deluxe Edition Edition includes: ‘DP-5...
# 1245620  Early Purchase Purchase now and get the follow...
#
#                                             about_the_game  \
# AppID
# 359550   “One of the best first-person shooters ever ma...
# 252490   The only aim in Rust is to survive. Everything...
# 1091500  Cyberpunk 2077 is an open-world, action-advent...
# 553850   The Galaxy’s Last Line of Offence. Enlist in t...
# 1245620  THE NEW FANTASY ACTION RPG. Rise, Tarnished, a...
#
#                                          short_description  \
# AppID
# 359550   Tom Clancy's Rainbow Six® Siege is an elite, t...
# 252490   The only aim in Rust is to survive. Everything...
# 1091500  Cyberpunk 2077 is an open-world, action-advent...
# 553850   The Galaxy’s Last Line of Offence. Enlist in t...
# 1245620  THE NEW FANTASY ACTION RPG. Rise, Tarnished, a...
#
#                                                    reviews  ... peak_ccu  \
# AppID                                                       ...
# 359550                                                 NaN  ...    68162
# 252490   “Rust is one of the cruelest games on Steam, a...  ...   122371
# 1091500                                                NaN  ...    35065
# 553850                                                 NaN  ...    46813
# 1245620  “Put a ring on it.” 10/10 – IGN “An unmissable...  ...    53910
#
#                                                       tags pct_pos_total  \
# AppID
# 359550   {'FPS': 9689, 'PvP': 9073, 'e-sports': 9026, '...            85
# 252490   {'Survival': 17867, 'Crafting': 11333, 'Multip...            87
# 1091500  {'Cyberpunk': 6103, 'Open World': 5474, 'Nudit...            83
# 553850   {'Online Co-Op': 609, 'Third-Person Shooter': ...            73
# 1245620  {'Souls-like': 6048, 'Dark Fantasy': 4391, 'Op...            93
#
#          num_reviews_total  pct_pos_recent  num_reviews_recent  \
# AppID
# 359550             1091695              77               10566
# 252490              874762              86                9347
# 1091500             655887              94                8433
# 553850              641080              66              321958
# 1245620             607405              94                8942
#
#          metacritic_bool  recommendations_bool  estimated_owners_tri  \
# AppID
# 359550                 0                     1                     2
# 252490                 1                     1                     2
# 1091500                1                     1                     2
# 553850                 0                     1                     2
# 1245620                1                     1                     2
#
#         price_sqrt
# AppID
# 359550    4.471018
# 252490    6.323765
# 1091500   5.476313
# 553850    6.323765
# 1245620   7.745321
#
# [5 rows x 42 columns]

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Boolean

# %%
mainline_df[pp_predictors_all['to_make_boolean']].dtypes
# Out:
# website          object
# support_url      object
# support_email    object
# screenshots      object
# movies           object
# dtype: object

# %%
sum(mainline_df.movies == '[]')
# Out:
# 362

# %%
mainline_df.loc[359550,].isna()
# Out:
# Unnamed: 0              False
# name                    False
# release_date            False
# required_age            False
# price                   False
# dlc_count               False
# detailed_description    False
# about_the_game          False
# short_description       False
# reviews                  True
# website                 False
# support_url             False
# support_email            True
# windows                 False
# mac                     False
# linux                   False
# metacritic_score        False
# achievements            False
# recommendations         False
# notes                    True
# supported_languages     False
# full_audio_languages    False
# packages                False
# developers              False
# publishers              False
# categories              False
# genres                  False
# screenshots             False
# movies                  False
# positive                False
# negative                False
# estimated_owners        False
# peak_ccu                False
# tags                    False
# pct_pos_total           False
# num_reviews_total       False
# pct_pos_recent          False
# num_reviews_recent      False
# metacritic_bool         False
# recommendations_bool    False
# estimated_owners_tri    False
# price_sqrt              False
# Name: 359550, dtype: bool

# %%
# screenshots, movies: str value of '[]'
# website, support_url, support_email: .isna() will catch

def boolean_transform(value):
    if pd.isna(value):
        return 0
    elif value == '[]':
        return 0
    else:
        return 1

# %%
for bool_col in pp_predictors_all['to_make_boolean']:
    new_colname = bool_col + '_bool'
    mainline_df[new_colname] = mainline_df.copy()[bool_col].apply(boolean_transform)

# %%
boolean_colnames = [item + '_bool' for item in pp_predictors_all['to_make_boolean']]
boolean_colnames
# Out:
# ['website_bool',
#  'support_url_bool',
#  'support_email_bool',
#  'screenshots_bool',
#  'movies_bool']

# %%
mainline_df[pp_predictors_all['to_make_boolean']+boolean_colnames].head()
# Out:
#                             website  \
# AppID
# 359550     http://rainbow6.ubi.com/
# 252490   http://rust.facepunch.com/
# 1091500   https://www.cyberpunk.net
# 553850                          NaN
# 1245620                         NaN
#
#                                                support_url  \
# AppID
# 359550                              http://support.ubi.com
# 252490                http://support.facepunchstudios.com/
# 1091500                 http://en.cdprojektred.com/support
# 553850   https://www.playstation.com/en-us/games/helldi...
# 1245620             https://www.bandainamcoent.com/support
#
#                          support_email  \
# AppID
# 359550                             NaN
# 252490                             NaN
# 1091500                            NaN
# 553850   support@arrowhead.zendesk.com
# 1245620                            NaN
#
#                                                screenshots  \
# AppID
# 359550   ['https://cdn.akamai.steamstatic.com/steam/app...
# 252490   ['https://cdn.akamai.steamstatic.com/steam/app...
# 1091500  ['https://cdn.akamai.steamstatic.com/steam/app...
# 553850   ['https://shared.akamai.steamstatic.com/store_...
# 1245620  ['https://cdn.akamai.steamstatic.com/steam/app...
#
#                                                     movies  website_bool  \
# AppID
# 359550   ['http://cdn.akamai.steamstatic.com/steam/apps...             1
# 252490   ['http://cdn.akamai.steamstatic.com/steam/apps...             1
# 1091500  ['http://cdn.akamai.steamstatic.com/steam/apps...             1
# 553850   ['http://cdn.akamai.steamstatic.com/steam/apps...             0
# 1245620  ['http://cdn.akamai.steamstatic.com/steam/apps...             0
#
#          support_url_bool  support_email_bool  screenshots_bool  movies_bool
# AppID
# 359550                  1                   0                 1            1
# 252490                  1                   0                 1            1
# 1091500                 1                   0                 1            1
# 553850                  1                   1                 1            1
# 1245620                 1                   0                 1            1

# %%
for temp_colname in boolean_colnames:
    temp_0 = sum(mainline_df[temp_colname] == 0)
    temp_1 = sum(mainline_df[temp_colname] == 1)
    print(f"{temp_colname} 0: {temp_0} || 1: {temp_1} || Check: {temp_0 + temp_1 == mainline_df.shape[0]} || prop_0: {round(temp_0/(temp_0+temp_1), 3)}")
# Out:
# website_bool 0: 5690 || 1: 10628 || Check: True || prop_0: 0.349
# support_url_bool 0: 6118 || 1: 10200 || Check: True || prop_0: 0.375
# support_email_bool 0: 3058 || 1: 13260 || Check: True || prop_0: 0.187
# screenshots_bool 0: 5 || 1: 16313 || Check: True || prop_0: 0.0
# movies_bool 0: 362 || 1: 15956 || Check: True || prop_0: 0.022

# %%
# Only include columns where more than 25% are missing (otherwise not enough data to be useful)
main_model_predictors += ['website_bool', 'support_url_bool']
main_model_predictors
# Out:
# ['website_bool', 'support_url_bool']

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Integer
# Make integer columns

# %%
mainline_df[pp_predictors_all['to_make_integer']].head()
# Out:
#                                        supported_languages  \
# AppID
# 359550   ['English', 'French', 'Italian', 'German', 'Sp...
# 252490   ['English', 'French', 'Italian', 'German', 'Sp...
# 1091500  ['English', 'French', 'Italian', 'German', 'Sp...
# 553850   ['English', 'French', 'Italian', 'German', 'Sp...
# 1245620  ['English', 'French', 'Italian', 'German', 'Sp...
#
#                                       full_audio_languages
# AppID
# 359550   ['English', 'French', 'Italian', 'German', 'Sp...
# 252490   ['English', 'French', 'Italian', 'German', 'Sp...
# 1091500  ['English', 'French', 'Italian', 'German', 'Sp...
# 553850   ['English', 'French', 'Italian', 'German', 'Sp...
# 1245620                 ['English', 'Traditional Chinese']

# %%
def converted_list_length(value):
    return len(ast.literal_eval(value))

for temp_intcol in pp_predictors_all['to_make_integer']:
    int_colname = temp_intcol + '_int'
    mainline_df[int_colname] = mainline_df.copy()[temp_intcol].apply(converted_list_length)

# %%
int_colnames = [colname+'_int' for colname in pp_predictors_all['to_make_integer']]
int_colnames
# Out:
# ['supported_languages_int', 'full_audio_languages_int']

# %%
print(mainline_df.loc[359550,'supported_languages'])
print(mainline_df.loc[359550,'supported_languages_int'])
# Out:
# ['English', 'French', 'Italian', 'German', 'Spanish - Spain', 'Czech', 'Dutch', 'Japanese', 'Korean', 'Polish', 'Portuguese - Brazil', 'Russian', 'Traditional Chinese', 'Simplified Chinese', 'Turkish', 'Thai']
# 16

# %%
print(mainline_df.loc[1091500,'full_audio_languages'])
print(mainline_df.loc[1091500,'full_audio_languages_int'])
# Out:
# ['English', 'French', 'Italian', 'German', 'Spanish - Spain', 'Japanese', 'Korean', 'Polish', 'Portuguese - Brazil', 'Russian', 'Simplified Chinese', 'Ukrainian']
# 12

# %%
main_model_predictors += int_colnames
main_model_predictors
# Out:
# ['website_bool',
#  'support_url_bool',
#  'supported_languages_int',
#  'full_audio_languages_int']

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Handling Lists</span>
# The work necessary to convert lists to the correct values, then do the proper encoding, is in this section.

# %%
mainline_df[pp_predictors_all['list_like']].head()
# Out:
#                          developers  \
# AppID
# 359550         ['Ubisoft Montreal']
# 252490        ['Facepunch Studios']
# 1091500          ['CD PROJEKT RED']
# 553850   ['Arrowhead Game Studios']
# 1245620       ['FromSoftware Inc.']
#
#                                                 publishers  \
# AppID
# 359550                                         ['Ubisoft']
# 252490                               ['Facepunch Studios']
# 1091500                                 ['CD PROJEKT RED']
# 553850                              ['PlayStation PC LLC']
# 1245620  ['FromSoftware Inc.', 'Bandai Namco Entertainm...
#
#                                                 categories  \
# AppID
# 359550   ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 252490   ['Multi-player', 'MMO', 'PvP', 'Online PvP', '...
# 1091500  ['Single-player', 'Steam Achievements', 'Full ...
# 553850   ['Multi-player', 'Co-op', 'Online Co-op', 'Ste...
# 1245620  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                                     genres
# AppID
# 359550                                          ['Action']
# 252490   ['Action', 'Adventure', 'Indie', 'Massively Mu...
# 1091500                                            ['RPG']
# 553850                                          ['Action']
# 1245620                                  ['Action', 'RPG']

# %%
# convert these to int columns to get counts; if any only ever have one value, can turn those to object columns
list_countcolnames = [col_name+'_count' for col_name in pp_predictors_all['list_like']]

def converted_list_length(value):
    return len(ast.literal_eval(value))

for temp_intcol in pp_predictors_all['list_like']:
    count_colname = temp_intcol + '_count'
    mainline_df[count_colname] = mainline_df.copy()[temp_intcol].apply(converted_list_length)

# %%
mainline_df[list_countcolnames].nunique()
# Out:
# developers_count    10
# publishers_count     4
# categories_count    24
# genres_count        11
# dtype: int64

# %% [markdown]
# The count of these are likely not important. It's likely that having 2 or more developers on a game may have no relationship to the quality; and the same could be said for publishers. I could see number of categories and genres being related to popularity, but it is likely that the actual values of these features are more strongly related.
#
# These should be included in a second or third model--that is, predicting the targets with just developers and publishers, and then with just categories and/or genres. Multiple models will increase interpretive complexity but will reduce dimensionality.
#
# To do this, I would create new DataFrames for each model, and create columns with Boolean values reflecting whether each value appeared in the list. However, this is only feasible if there aren't too many unique values in each. There may be too many publishers and developers to model, but may be able to identify grouped average for price and get some information that way.

# %%
from datetime import datetime

# get counts of all values for each feature
all_names_dict = {'developers': {},#{'value': [], 'count': 0},
                  'publishers': {},#{'value': [], 'count': 0},
                  'categories': {},#{'value': [], 'count': 0},
                  'genres': {}#{'value': [], 'count': 0}}
                 }
print(f"Start time: {datetime.now().strftime("%H:%M:%S")}")

for temp_key in all_names_dict.keys():
    row_count = 0
    #print(f"temp_key: {temp_key}")#temp_values_list = []
    for temp_entry in mainline_df[temp_key]:
        row_count += 1
        #print(f"temp_entry: {temp_entry}")
        temp_list = ast.literal_eval(temp_entry)
        #print(f"temp_list: {temp_list} || length: {len(temp_list)}")
        if len(temp_list) == 1:
            if temp_list[0] not in all_names_dict[temp_key].keys():
                all_names_dict[temp_key][temp_list[0]] = 0
            all_names_dict[temp_key][temp_list[0]] += 1
        else:
            for temp_value in temp_list:
                if temp_value not in all_names_dict[temp_key].keys(): #temp_values_list:
                    all_names_dict[temp_key][temp_value] = 0
                all_names_dict[temp_key][temp_value] += 1
        
        #print(f"current: {all_names_dict[temp_key]}")
    print(f"--Complete: {temp_key}. Time: {datetime.now().strftime("%H:%M:%S")}")

print(f"End time: {datetime.now().strftime("%H:%M:%S")}")
# Out:
# Start time: 20:46:57
# --Complete: developers. Time: 20:46:57
# --Complete: publishers. Time: 20:46:58
# --Complete: categories. Time: 20:46:58
# --Complete: genres. Time: 20:46:58
# End time: 20:46:58

# %%
# Print the counts of unique values contained within each feature--this will show how many features extra models would have
for temp_key in all_names_dict.keys():
    print(f"{temp_key} -- {len(all_names_dict[temp_key])}")
# Out:
# developers -- 12072
# publishers -- 9054
# categories -- 39
# genres -- 27

# %%
pd.DataFrame({'developer_names': all_names_dict['developers'].keys(), 'counts': all_names_dict['developers'].values()}).sort_values('counts', ascending=False).head()
# Out:
#                  developer_names  counts
# 300   KOEI TECMO GAMES CO., LTD.     101
# 96                   Square Enix      73
# 9195         Individual Software      42
# 7972             CyberStep, Inc.      41
# 8964       Rideon Works Co. Ltd,      38

# %% [markdown]
# Developers likely don't show up often enough to be useful; far too imbalanced to use for anything other than TargetEncoding, but how would that work due to an overlap of developers within games.

# %%
pd.DataFrame({'publisher_names': all_names_dict['publishers'].keys(), 'counts': all_names_dict['publishers'].values()}).sort_values('counts', ascending=False).head(n = 10)
# Out:
#                  publisher_names  counts
# 289                 Kagura Games     126
# 87                          SEGA     102
# 197   KOEI TECMO GAMES CO., LTD.      96
# 69                   Square Enix      95
# 475                Sekai Project      93
# 376              Slitherine Ltd.      92
# 201                   THQ Nordic      79
# 39               Electronic Arts      74
# 5036              Big Fish Games      71
# 382                        Nacon      68

# %%
pd.DataFrame({'category_names': all_names_dict['categories'].keys(), 'counts': all_names_dict['categories'].values()}).sort_values('counts', ascending=False)
# Out:
#                 category_names  counts
# 18              Family Sharing   15715
# 0                Single-player   15494
# 13          Steam Achievements    9301
# 17                 Steam Cloud    6879
# 6      Full controller support    5252
# 1                 Multi-player    4143
# 7          Steam Trading Cards    3528
# 19  Partial Controller Support    2456
# 4                        Co-op    2446
# 2                          PvP    2440
# 3                   Online PvP    1829
# 23        Remote Play Together    1779
# 22         Shared/Split Screen    1617
# 5                 Online Co-op    1492
# 24  Tracked Controller Support    1460
# 29          Steam Leaderboards    1342
# 36                     VR Only    1287
# 33     Shared/Split Screen PvP    1113
# 26           Remote Play on TV    1089
# 21   Shared/Split Screen Co-op    1069
# 14              Steam Workshop     838
# 16                       Stats     739
# 12  Cross-Platform Multiplayer     640
# 27       Includes level editor     632
# 10       Remote Play on Tablet     483
# 9         Remote Play on Phone     375
# 32          Captions available     368
# 25                VR Supported     361
# 20                   LAN Co-op     214
# 28                     LAN PvP     201
# 8             In-App Purchases     195
# 11                         MMO     165
# 31                  VR Support      84
# 30               HDR available      66
# 37        Commentary available      51
# 15    Valve Anti-Cheat enabled      48
# 38        SteamVR Collectibles      26
# 34    Steam Turn Notifications      24
# 35         Includes Source SDK       7

# %%
pd.DataFrame({'genre_names': all_names_dict['genres'].keys(), 'counts': all_names_dict['genres'].values()}).sort_values('counts', ascending=False)
# Out:
#               genre_names  counts
# 2                   Indie    9775
# 1               Adventure    7412
# 0                  Action    6897
# 9                  Casual    4376
# 5              Simulation    4304
# 4                     RPG    4055
# 7                Strategy    3657
# 6            Early Access    2481
# 10                 Sports     935
# 8                  Racing     613
# 3   Massively Multiplayer     304
# 16              Utilities     212
# 22  Design & Illustration     180
# 21   Animation & Modeling     130
# 23              Education     119
# 20       Game Development     103
# 18       Video Production      93
# 19      Software Training      82
# 17       Audio Production      73
# 12                Violent      60
# 24          Photo Editing      50
# 26         Web Publishing      42
# 13                   Gore      41
# 11                 Nudity      14
# 14         Sexual Content      13
# 15           Free to Play       9
# 25             Accounting       7

# %% [markdown]
# It looks like categories and genres may be useful to look at, but not developers and publishers, due to low category representation.

# %%
mainline_df['categories'].str.contains('ingle').head()
# Out:
# AppID
# 359550      True
# 252490     False
# 1091500     True
# 553850     False
# 1245620     True
# Name: categories, dtype: bool

# %%
catgen_model_predictors = ['categories', 'genres']
catgen_model_cols = {}

for base_feature in catgen_model_predictors:
    for feature_category in all_names_dict[base_feature].keys():
        temp_featurename = base_feature+'_'+feature_category.lower().replace(' ','_') # improve naming conventions
        catgen_model_cols[temp_featurename] = np.where(mainline_df[base_feature].str.contains(feature_category), 1, 0)

# %%
catgen_df = pd.DataFrame(catgen_model_cols, index = mainline_df.index)
catgen_df.head()
# Out:
#          categories_single-player  categories_multi-player  categories_pvp  \
# AppID
# 359550                          1                        1               1
# 252490                          0                        1               1
# 1091500                         1                        0               0
# 553850                          0                        1               0
# 1245620                         1                        1               1
#
#          categories_online_pvp  categories_co-op  categories_online_co-op  \
# AppID
# 359550                       1                 1                        1
# 252490                       1                 1                        1
# 1091500                      0                 0                        0
# 553850                       0                 1                        1
# 1245620                      1                 1                        1
#
#          categories_full_controller_support  categories_steam_trading_cards  \
# AppID
# 359550                                    1                               1
# 252490                                    0                               1
# 1091500                                   1                               1
# 553850                                    0                               0
# 1245620                                   1                               1
#
#          categories_in-app_purchases  categories_remote_play_on_phone  ...  \
# AppID                                                                  ...
# 359550                             1                                1  ...
# 252490                             1                                0  ...
# 1091500                            0                                0  ...
# 553850                             1                                0  ...
# 1245620                            0                                0  ...
#
#          genres_audio_production  genres_video_production  \
# AppID
# 359550                         0                        0
# 252490                         0                        0
# 1091500                        0                        0
# 553850                         0                        0
# 1245620                        0                        0
#
#          genres_software_training  genres_game_development  \
# AppID
# 359550                          0                        0
# 252490                          0                        0
# 1091500                         0                        0
# 553850                          0                        0
# 1245620                         0                        0
#
#          genres_animation_&_modeling  genres_design_&_illustration  \
# AppID
# 359550                             0                             0
# 252490                             0                             0
# 1091500                            0                             0
# 553850                             0                             0
# 1245620                            0                             0
#
#          genres_education  genres_photo_editing  genres_accounting  \
# AppID
# 359550                  0                     0                  0
# 252490                  0                     0                  0
# 1091500                 0                     0                  0
# 553850                  0                     0                  0
# 1245620                 0                     0                  0
#
#          genres_web_publishing
# AppID
# 359550                       0
# 252490                       0
# 1091500                      0
# 553850                       0
# 1245620                      0
#
# [5 rows x 66 columns]

# %%
pd.concat([catgen_df.iloc[:5,1:3], mainline_df.loc[359550:1245620,'categories']], axis = 1)
# Out:
#          categories_multi-player  categories_pvp  \
# AppID
# 359550                         1               1
# 252490                         1               1
# 1091500                        0               0
# 553850                         1               0
# 1245620                        1               1
#
#                                                 categories
# AppID
# 359550   ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 252490   ['Multi-player', 'MMO', 'PvP', 'Online PvP', '...
# 1091500  ['Single-player', 'Steam Achievements', 'Full ...
# 553850   ['Multi-player', 'Co-op', 'Online Co-op', 'Ste...
# 1245620  ['Single-player', 'Multi-player', 'PvP', 'Onli...

# %% [markdown]
# The above looks like it worked. 'Co-op' and 'PvP' are common terms; see if there are ever instances where they appear when their more specific versions do not. If not, remove those columns.

# %%
catgen_df[[col for col in catgen_df.columns if 'pvp' in col.lower()]].value_counts()
# Out:
# categories_pvp  categories_online_pvp  categories_lan_pvp  categories_shared/split_screen_pvp
# 0               0                      0                   0                                     13877
# 1               1                      0                   0                                      1136
#                 0                      0                   1                                       571
#                 1                      0                   1                                       509
#                                        1                   0                                       154
#                                                            1                                        30
#                 0                      0                   0                                        24
#                                        1                   0                                        14
#                                                            1                                         3
# Name: count, dtype: int64

# %%
catgen_df[[col for col in catgen_df.columns if 'co-op' in col.lower()]].value_counts()
# Out:
# categories_co-op  categories_online_co-op  categories_lan_co-op  categories_shared/split_screen_co-op
# 0                 0                        0                     0                                       13870
# 1                 1                        0                     0                                        1001
#                   0                        0                     1                                         739
#                   1                        0                     1                                         298
#                   0                        0                     0                                         196
#                   1                        1                     0                                         162
#                                                                  1                                          31
#                   0                        1                     0                                          20
#                                                                  1                                           1
# Name: count, dtype: int64

# %%
catgen_df.drop(['categories_co-op', 'categories_pvp'], axis = 1, inplace=True)
catgen_df.columns
# Out:
# Index(['categories_single-player', 'categories_multi-player',
#        'categories_online_pvp', 'categories_online_co-op',
#        'categories_full_controller_support', 'categories_steam_trading_cards',
#        'categories_in-app_purchases', 'categories_remote_play_on_phone',
#        'categories_remote_play_on_tablet', 'categories_mmo',
#        'categories_cross-platform_multiplayer',
#        'categories_steam_achievements', 'categories_steam_workshop',
#        'categories_valve_anti-cheat_enabled', 'categories_stats',
#        'categories_steam_cloud', 'categories_family_sharing',
#        'categories_partial_controller_support', 'categories_lan_co-op',
#        'categories_shared/split_screen_co-op',
#        'categories_shared/split_screen', 'categories_remote_play_together',
#        'categories_tracked_controller_support', 'categories_vr_supported',
#        'categories_remote_play_on_tv', 'categories_includes_level_editor',
#        'categories_lan_pvp', 'categories_steam_leaderboards',
#        'categories_hdr_available', 'categories_vr_support',
#        'categories_captions_available', 'categories_shared/split_screen_pvp',
#        'categories_steam_turn_notifications', 'categories_includes_source_sdk',
#        'categories_vr_only', 'categories_commentary_available',
#        'categories_steamvr_collectibles', 'genres_action', 'genres_adventure',
#        'genres_indie', 'genres_massively_multiplayer', 'genres_rpg',
#        'genres_simulation', 'genres_early_access', 'genres_strategy',
#        'genres_racing', 'genres_casual', 'genres_sports', 'genres_nudity',
#        'genres_violent', 'genres_gore', 'genres_sexual_content',
#        'genres_free_to_play', 'genres_utilities', 'genres_audio_production',
#        'genres_video_production', 'genres_software_training',
#        'genres_game_development', 'genres_animation_&_modeling',
#        'genres_design_&_illustration', 'genres_education',
#        'genres_photo_editing', 'genres_accounting', 'genres_web_publishing'],
#       dtype='object')

# %% [markdown]
# Good--will add the target columns to this when that preprocessing is done.
#
# Also drop any features with <10% presence in the data

# %%
catgen_drop_features = catgen_df.columns[catgen_df.sum() < (catgen_df.shape[0]/10)]
catgen_df.drop(catgen_drop_features, axis=1, inplace=True)
catgen_df.sum()
# Out:
# categories_single-player                 15494
# categories_multi-player                   4143
# categories_online_pvp                     1829
# categories_full_controller_support        5252
# categories_steam_trading_cards            3528
# categories_steam_achievements             9301
# categories_steam_cloud                    6879
# categories_family_sharing                15715
# categories_partial_controller_support     2456
# categories_shared/split_screen            1853
# categories_remote_play_together           1779
# genres_action                             6897
# genres_adventure                          7412
# genres_indie                              9775
# genres_rpg                                4055
# genres_simulation                         4304
# genres_early_access                       2481
# genres_strategy                           3657
# genres_casual                             4376
# dtype: int64

# %%
model_df_list['categories'] = catgen_df
model_df_list.keys()
# Out:
# dict_keys(['main', 'categories'])

# %% [markdown]
# ### <span style="color: Teal; font-weight: bold">Handling JSON-like features</span>

# %%
mainline_df['tags'].head()
# Out:
# AppID
# 359550     {'FPS': 9689, 'PvP': 9073, 'e-sports': 9026, '...
# 252490     {'Survival': 17867, 'Crafting': 11333, 'Multip...
# 1091500    {'Cyberpunk': 6103, 'Open World': 5474, 'Nudit...
# 553850     {'Online Co-Op': 609, 'Third-Person Shooter': ...
# 1245620    {'Souls-like': 6048, 'Dark Fantasy': 4391, 'Op...
# Name: tags, dtype: object

# %% [markdown]
# The `tags` feature is a dictionary-like string feature containing tag names and counts. There are multiple ways I could code this:
# - Just get a Boolean representation if a tag is present for a game
# - Get a count of how many tags are present for each game (which could be an indirect metric of popularity)
# - Get a raw count of tag value for each game
# - Get a normalized count of tag value for each game, accounting for the total number of people played
#
# We can't get a good estimate of number of people who play the game, so number three is out--any normalization process won't be sensitive enough just using the range from `estimated_owners`. Any predictive feature matrix will be a relatively sparse matrix, since most games will have relatively few tags attached to them.
#
# I think this should be handled in two ways--another model, using the presence of a tag to predict targets (e.g., Boolean), and a single count value added to the original model.
#
# **Add `tags_count` to mainline_df:**

# %%
mainline_df['tags_count'] = mainline_df.copy()['tags'].apply(lambda x: x.count(':'))

mainline_df[['tags', 'tags_count']].head()
# Out:
#                                                       tags  tags_count
# AppID
# 359550   {'FPS': 9689, 'PvP': 9073, 'e-sports': 9026, '...          20
# 252490   {'Survival': 17867, 'Crafting': 11333, 'Multip...          20
# 1091500  {'Cyberpunk': 6103, 'Open World': 5474, 'Nudit...          20
# 553850   {'Online Co-Op': 609, 'Third-Person Shooter': ...          20
# 1245620  {'Souls-like': 6048, 'Dark Fantasy': 4391, 'Op...          20

# %%
mainline_df['tags_count'].hist()
# Out:
# <Axes: >

# %%
mainline_df.plot(kind = 'scatter', x = 'tags_count', y = 'price', alpha = 0.2)
# Out:
# <Axes: xlabel='tags_count', ylabel='price'>

# %% [markdown]
# This may still be useful--add it to the main model

# %%
main_model_predictors += ['tags_count']
main_model_predictors
# Out:
# ['website_bool',
#  'support_url_bool',
#  'supported_languages_int',
#  'full_audio_languages_int',
#  'tags_count']

# %% [markdown]
# **Create third model for tags**

# %%
# get base of all tags, then for each observation, add an indicator if more than 1/3 the max tag value identified that tag for that game (avoid spurious tags)
base_tags = mainline_df.copy().tags

# %%
# get list of tags
tags_list_dict = {'Total': 0}

# Iterate over each row in the 'tags' column
for tags_dict in base_tags:
    tags_list_dict['Total'] += 1
    # Update the set with keys from the current dict
    tags_dict = ast.literal_eval(tags_dict)
    if not isinstance(tags_dict, dict):
        continue
    for temp_key in tags_dict:
        if temp_key not in tags_list_dict.keys():
            tags_list_dict[temp_key] = 0
        tags_list_dict[temp_key] += 1#tags_dict[temp_key]

# %%
base_tags_df = pd.DataFrame(tags_list_dict, index = ['Count']).T.sort_values('Count',ascending = False)
base_tags_df
# Out:
#                                    Count
# Total                              16318
# Singleplayer                        9800
# Adventure                           7207
# Indie                               7127
# Action                              6808
# Casual                              4282
# Simulation                          4196
# RPG                                 3886
# Story Rich                          3844
# 2D                                  3841
# Strategy                            3686
# Atmospheric                         3493
# 3D                                  3098
# Exploration                         2918
# Multiplayer                         2908
# Early Access                        2820
# Fantasy                             2759
# First-Person                        2497
# Anime                               2431
# Colorful                            2406
# Cute                                2352
# Puzzle                              2186
# Female Protagonist                  2144
# Open World                          2122
# Sci-fi                              2047
# Action-Adventure                    1875
# Pixel Graphics                      1845
# Funny                               1832
# Third Person                        1719
# Shooter                             1717
# Co-op                               1634
# Sandbox                             1623
# Great Soundtrack                    1600
# Family Friendly                     1580
# VR                                  1523
# Visual Novel                        1464
# Controller                          1456
# Arcade                              1454
# Horror                              1451
# Survival                            1440
# Realistic                           1387
# Choices Matter                      1376
# Combat                              1341
# Difficult                           1327
# Retro                               1310
# Platformer                          1278
# Building                            1251
# FPS                                 1231
# Comedy                              1223
# Character Customization             1218
# Management                          1203
# Multiple Endings                    1202
# Violent                             1201
# Relaxing                            1194
# Stylized                            1161
# Mystery                             1145
# Tactical                            1134
# Action RPG                          1129
# PvP                                 1108
# Turn-Based Strategy                 1081
# Crafting                            1068
# Top-Down                            1051
# Turn-Based Combat                   1027
# Sexual Content                      1022
# Gore                                1021
# JRPG                                1016
# Physics                              996
# Sports                               962
# Local Multiplayer                    959
# Rogue-like                           950
# Dark                                 944
# Online Co-Op                         943
# Cartoony                             926
# Nudity                               925
# Rogue-lite                           916
# Space                                910
# Magic                                905
# Turn-Based Tactics                   885
# Base-Building                        875
# Resource Management                  843
# Hack and Slash                       840
# Point & Click                        830
# Procedural Generation                827
# Turn-Based                           815
# Local Co-Op                          814
# Psychological Horror                 803
# PvE                                  782
# Choose Your Own Adventure            782
# Immersive Sim                        780
# 2D Platformer                        779
# Historical                           775
# Side Scroller                        770
# Hand-drawn                           764
# Romance                              745
# Futuristic                           737
# War                                  732
# Dark Fantasy                         732
# Medieval                             731
# Drama                                730
# Replay Value                         693
# Dungeon Crawler                      677
# Post-apocalyptic                     647
# Old School                           634
# Racing                               631
# Isometric                            628
# Emotional                            626
# Military                             614
# Linear                               613
# Survival Horror                      601
# Dating Sim                           590
# Economy                              572
# Puzzle-Platformer                    570
# Interactive Fiction                  570
# 3D Platformer                        568
# RTS                                  563
# Action Roguelike                     549
# Cartoon                              526
# Strategy RPG                         520
# City Builder                         520
# Education                            519
# Zombies                              502
# Stealth                              497
# Mature                               496
# Shoot 'Em Up                         489
# Tactical RPG                         485
# Nature                               471
# Detective                            459
# Cinematic                            457
# Hidden Object                        457
# 2.5D                                 453
# 1990's                               447
# Cyberpunk                            443
# Narration                            442
# Wargame                              441
# Surreal                              441
# Party-Based RPG                      439
# Driving                              437
# LGBTQ+                               431
# Bullet Hell                          431
# Walking Simulator                    430
# Life Sim                             427
# Third-Person Shooter                 421
# Investigation                        421
# Lore-Rich                            420
# 4 Player Local                       418
# Moddable                             417
# Robots                               414
# Logic                                413
# Card Game                            406
# Real Time Tactics                    403
# Metroidvania                         402
# Classic                              375
# Text-Based                           373
# Beat 'em up                          358
# Aliens                               352
# Fast-Paced                           350
# Souls-like                           346
# Hentai                               345
# Fighting                             343
# Dark Humor                           336
# Time Management                      336
# Grand Strategy                       333
# Perma Death                          329
# Board Game                           328
# Flight                               323
# Minimalist                           323
# Deckbuilding                         320
# Alternate History                    317
# Conversation                         316
# Automobile Sim                       310
# Demons                               310
# Competitive                          307
# Dystopian                            306
# Score Attack                         304
# Loot                                 304
# Memes                                302
# Level Editor                         301
# Nonlinear                            299
# Comic Book                           299
# Top-Down Shooter                     298
# Team-Based                           295
# Thriller                             285
# Music                                282
# Tabletop                             279
# Artificial Intelligence              279
# Tower Defense                        278
# CRPG                                 276
# Design & Illustration                275
# Open World Survival Craft            272
# Massively Multiplayer                268
# Psychological                        267
# Modern                               265
# Destruction                          262
# RPGMaker                             262
# Soundtrack                           260
# Colony Sim                           259
# Tutorial                             257
# Card Battler                         256
# Supernatural                         255
# Space Sim                            255
# Inventory Management                 252
# World War II                         249
# Crime                                246
# Collectathon                         246
# Utilities                            244
# Mythology                            242
# 1980s                                238
# Farming Sim                          236
# NSFW                                 236
# Rhythm                               230
# Split Screen                         229
# 2D Fighter                           222
# Swordplay                            218
# Arena Shooter                        216
# 6DOF                                 208
# Beautiful                            206
# Precision Platformer                 205
# Psychedelic                          204
# Automation                           203
# Agriculture                          203
# Remake                               202
# Parkour                              200
# Mechs                                200
# Twin Stick Shooter                   198
# Science                              198
# Steampunk                            192
# e-sports                             191
# Software                             190
# Lovecraftian                         190
# Grid-Based Movement                  190
# Co-op Campaign                       181
# 4X                                   180
# Class-Based                          179
# Creature Collector                   170
# Abstract                             168
# Otome                                167
# Martial Arts                         167
# Trading                              164
# Animation & Modeling                 164
# Short                                163
# Game Development                     163
# Dragons                              162
# Dark Comedy                          161
# Vehicular Combat                     161
# Experimental                         161
# Cooking                              160
# Hex Grid                             159
# Capitalism                           156
# 3D Fighter                           152
# America                              152
# Gun Customization                    151
# Spectacle fighter                    149
# Gothic                               148
# Cats                                 147
# Noir                                 146
# Political                            144
# Real-Time                            143
# Real-Time with Pause                 143
# Character Action Game                139
# Pirates                              139
# Narrative                            138
# Mystery Dungeon                      135
# Transportation                       134
# Mining                               134
# Bullet Time                          134
# Diplomacy                            134
# God Game                             132
# Voxel                                132
# 3D Vision                            130
# Roguelike Deckbuilder                129
# Ninja                                128
# Philosophical                        127
# Fishing                              127
# Time Travel                          125
# Hunting                              124
# Time Manipulation                    123
# Programming                          121
# Political Sim                        121
# Wholesome                            120
# Blood                                119
# Trains                               117
# Looter Shooter                       117
# Combat Racing                        116
# Cozy                                 113
# Naval                                112
# Tanks                                111
# Immersive                            110
# FMV                                  108
# Kickstarter                          108
# Action RTS                           107
# Dynamic Narration                    107
# Cult Classic                         104
# Politics                             104
# Dog                                  103
# Conspiracy                           102
# Runner                               102
# Clicker                              102
# Hero Shooter                         102
# Underwater                           100
# Video Production                      98
# Parody                                97
# Faith                                 97
# Party                                 96
# Audio Production                      95
# Word Game                             94
# Hacking                               93
# Boomer Shooter                        92
# Vampire                               92
# Party Game                            91
# Superhero                             91
# Dinosaurs                             90
# Asynchronous Multiplayer              88
# Software Training                     86
# Naval Combat                          86
# Assassin                              85
# MMORPG                                83
# Offroad                               81
# Addictive                             80
# Villain Protagonist                   79
# Archery                               79
# Satire                                79
# Auto Battler                          77
# Sailing                               77
# Underground                           75
# Battle Royale                         74
# Mouse only                            74
# Cold War                              73
# Quick-Time Events                     73
# Minigames                             72
# Horses                                72
# Western                               72
# Heist                                 71
# Photo Editing                         70
# Motorbike                             70
# Free to Play                          69
# Escape Room                           67
# Bikes                                 66
# On-Rails Shooter                      65
# Nostalgia                             64
# Sequel                                59
# Traditional Roguelike                 58
# Match 3                               58
# Crowdfunded                           56
# Idler                                 55
# Snow                                  55
# Solitaire                             55
# Epic                                  55
# Farming                               55
# World War I                           54
# Illuminati                            53
# Music-Based Procedural Generation     53
# Web Publishing                        53
# Transhumanism                         52
# Trading Card Game                     52
# Mars                                  51
# Boxing                                51
# Typing                                49
# MOBA                                  49
# Time Attack                           49
# Trivia                                48
# Foreign                               48
# Football (American)                   47
# Medical Sim                           44
# Games Workshop                        43
# Asymmetric VR                         42
# Rome                                  41
# Jet                                   41
# LEGO                                  41
# Roguevania                            40
# Episodic                              40
# Football (Soccer)                     39
# Sokoban                               38
# Experience                            38
# Basketball                            37
# Golf                                  37
# Spaceships                            37
# Outbreak Sim                          37
# Unforgiving                           35
# Dwarf                                 34
# Gambling                              33
# Submarine                             32
# Dungeons & Dragons                    32
# Sniper                                31
# GameMaker                             30
# Warhammer 40K                         30
# Wrestling                             30
# Electronic Music                      28
# Vikings                               28
# Movie                                 28
# Chess                                 27
# Tennis                                27
# Baseball                              27
# Mod                                   26
# Cycling                               26
# Motocross                             26
# Skateboarding                         26
# Musou                                 25
# Touch-Friendly                        25
# Pinball                               24
# Werewolves                            23
# Spelling                              22
# Skating                               21
# Gaming                                21
# 360 Video                             21
# Based On A Novel                      21
# Silent Protagonist                    20
# Job Simulator                         20
# Social Deduction                      20
# Hockey                                19
# Mini Golf                             19
# Ambient                               18
# TrackIR                               17
# Well-Written                          16
# Snowboarding                          15
# Rock Music                            15
# Pool                                  15
# Voice Control                         14
# Rugby                                 14
# Boss Rush                             13
# Skiing                                13
# BMX                                   12
# ATV                                   12
# Lemmings                              11
# Bowling                               11
# Extraction Shooter                    11
# Electronic                             9
# Instrumental Music                     9
# Intentionally Awkward Controls         9
# Masterpiece                            9
# Hardware                               9
# Cricket                                9
# Benchmark                              8
# Jump Scare                             8
# Coding                                 7
# Shop Keeper                            7
# 8-bit Music                            6
# Reboot                                 6
# Documentary                            5
# Steam Machine                          5
# Birds                                  5
# Volleyball                             5
# Hobby Sim                              5
# Mahjong                                4
# Fox                                    4
# Snooker                                3
# VR Only                                2
# Elf                                    2
# Tile-Matching                          2

# %%
# Only keep values with counts at least 1/10 of total
minimum_value = len(mainline_df)/10
print(minimum_value)
sum(base_tags_df.Count > minimum_value)
# Out:
# 1631.8
# 31

# %%
base_tags = list(base_tags_df.copy()[base_tags_df.Count > minimum_value].index)
del base_tags[0] # 'Total' isn't a real tag
base_tags
# Out:
# ['Singleplayer',
#  'Adventure',
#  'Indie',
#  'Action',
#  'Casual',
#  'Simulation',
#  'RPG',
#  'Story Rich',
#  '2D',
#  'Strategy',
#  'Atmospheric',
#  '3D',
#  'Exploration',
#  'Multiplayer',
#  'Early Access',
#  'Fantasy',
#  'First-Person',
#  'Anime',
#  'Colorful',
#  'Cute',
#  'Puzzle',
#  'Female Protagonist',
#  'Open World',
#  'Sci-fi',
#  'Action-Adventure',
#  'Pixel Graphics',
#  'Funny',
#  'Third Person',
#  'Shooter',
#  'Co-op']

# %%
print(base_tags)
# Out:
# ['Singleplayer', 'Adventure', 'Indie', 'Action', 'Casual', 'Simulation', 'RPG', 'Story Rich', '2D', 'Strategy', 'Atmospheric', '3D', 'Exploration', 'Multiplayer', 'Early Access', 'Fantasy', 'First-Person', 'Anime', 'Colorful', 'Cute', 'Puzzle', 'Female Protagonist', 'Open World', 'Sci-fi', 'Action-Adventure', 'Pixel Graphics', 'Funny', 'Third Person', 'Shooter', 'Co-op']

# %%
# Create indexable list with dict values for tags
tags_column_series = []
tags_tagvalues_series = []
for i in range(0, len(mainline_df)):
    tags_column_series.append(ast.literal_eval(mainline_df.copy().tags.iloc[i]))
    temp_str_value = ''
    if isinstance(tags_column_series[i], dict):
        for j in tags_column_series[i].keys():
            temp_str_value += j
        tags_tagvalues_series.append(temp_str_value)
    else:
        tags_tagvalues_series.append('')
    if i%1000 == 0:
        print(f"Iteration {i} complete.")
# Out:
# Iteration 0 complete.
# Iteration 1000 complete.
# Iteration 2000 complete.
# Iteration 3000 complete.
# Iteration 4000 complete.
# Iteration 5000 complete.
# Iteration 6000 complete.
# Iteration 7000 complete.
# Iteration 8000 complete.
# Iteration 9000 complete.
# Iteration 10000 complete.
# Iteration 11000 complete.
# Iteration 12000 complete.
# Iteration 13000 complete.
# Iteration 14000 complete.
# Iteration 15000 complete.
# Iteration 16000 complete.

# %%
# both should be True
print(len(tags_column_series) == len(mainline_df))
print(len(tags_tagvalues_series) == len(mainline_df))
# Out:
# True
# True

# %%
## Create a dict representing a DataFrame. The dict should have keys corresponding to tags and values representing whether the tag has a significant count
## (more than 1/3 the max tag count for that observation), so that the whole dict can be turned into a DataFrame that accurately maps onto mainline_df and can be
## indexed properly.

### Below: Create a dict to xform to a dataframe, containing correct number for tags in correct spaces
# Create an empty dict for this purpose, with each value holding a list
tags_num_df_dict = {'index': mainline_df.index}
for temp_tag in base_tags:
    tags_num_df_dict[temp_tag] = []

for i in range(0, len(mainline_df)): # Iterate over observations
    for temp_tag in base_tags:  # Iterate over temp_tag
        # if the tag is present in tags_tagvalues_series, it has a corresponding number entry in tags_column_series
        if isinstance(tags_column_series[i], dict):
            if temp_tag in tags_column_series[i].keys(): #tags_tagvalues_series[i]:
                tags_num_df_dict[temp_tag].append(tags_column_series[i][temp_tag])
        # if not, no tag present so value should be 0
            else:
                tags_num_df_dict[temp_tag].append(0)
        else:
            tags_num_df_dict[temp_tag].append(0)
    if i%1000 == 0:
        print(f"Iteration {i} complete.")
# Out:
# Iteration 0 complete.
# Iteration 1000 complete.
# Iteration 2000 complete.
# Iteration 3000 complete.
# Iteration 4000 complete.
# Iteration 5000 complete.
# Iteration 6000 complete.
# Iteration 7000 complete.
# Iteration 8000 complete.
# Iteration 9000 complete.
# Iteration 10000 complete.
# Iteration 11000 complete.
# Iteration 12000 complete.
# Iteration 13000 complete.
# Iteration 14000 complete.
# Iteration 15000 complete.
# Iteration 16000 complete.

# %%
print(len(tags_num_df_dict['Singleplayer']) == len(mainline_df))
# Out:
# True

# %%
tags_bool_df_dict = {'index': mainline_df.index}
for temp_tag in base_tags:
    tags_bool_df_dict[temp_tag] = []


for i in range(0, len(mainline_df)):
    for temp_tag in base_tags:
        if temp_tag in tags_tagvalues_series[i]:
            tags_bool_df_dict[temp_tag].append(1)
        else:
            tags_bool_df_dict[temp_tag].append(0)

# %%
pd.DataFrame({'value':tags_tagvalues_series,'Singleplayer':tags_bool_df_dict['Singleplayer']}).head()
# Out:
#                                                value  Singleplayer
# 0  FPSPvPe-sportsMultiplayerTacticalShooterCompet...             0
# 1  SurvivalCraftingMultiplayerOpen WorldOpen Worl...             0
# 2  CyberpunkOpen WorldNudityRPGSingleplayerSci-fi...             1
# 3  Online Co-OpThird-Person ShooterMultiplayerAct...             1
# 4  Souls-likeDark FantasyOpen WorldRPGDifficultAc...             1

# %%
pd.DataFrame({'value':tags_tagvalues_series,'RPG':tags_bool_df_dict['RPG']}).tail()
# Out:
#                                                    value  RPG
# 16313  WargameImmersive SimMilitaryDiplomacyWarTurn-B...    0
# 16314  FPSAction RTSTower DefenseRTSShooterStrategyFi...    0
# 16315  RPGAction RPGExplorationLootOld SchoolDungeon ...    1
# 16316                                                       0
# 16317                                                       0

# %%
tags_num_df = pd.DataFrame(tags_num_df_dict)
tags_num_df.set_index('index', inplace = True)
tags_num_df.head()
# Out:
#          Singleplayer  Adventure  Indie  Action  Casual  Simulation   RPG  \
# index
# 359550              0          0      0    8875       0           0     0
# 252490              0       5639   3003    4659       0        2461     0
# 1091500          4526       2074      0    2883       0           0  4591
# 553850            152          0      0     529       0           0     0
# 1245620          2769          0      0    2574       0           0  4160
#
#          Story Rich  2D  Strategy  ...  Puzzle  Female Protagonist  \
# index                              ...
# 359550            0   0      4859  ...       0                   0
# 252490            0   0         0  ...       0                   0
# 1091500        4069   0         0  ...       0                   0
# 553850            0   0         0  ...       0                   0
# 1245620           0   0         0  ...       0                   0
#
#          Open World  Sci-fi  Action-Adventure  Pixel Graphics  Funny  \
# index
# 359550            0       0                 0               0      0
# 252490        10699       0                 0               0      0
# 1091500        5474    4331                 0               0      0
# 553850          129     438                 0               0      0
# 1245620        4282       0                 0               0      0
#
#          Third Person  Shooter  Co-op
# index
# 359550              0     8944   4823
# 252490              0     3643   3615
# 1091500             0        0      0
# 553850            354      466    462
# 1245620          3082        0   2206
#
# [5 rows x 30 columns]

# %%
tags_bool_df = pd.DataFrame(tags_bool_df_dict)
tags_bool_df.set_index('index', inplace = True)
tags_bool_df.head()
# Out:
#          Singleplayer  Adventure  Indie  Action  Casual  Simulation  RPG  \
# index
# 359550              0          0      0       1       0           0    0
# 252490              0          1      1       1       0           1    0
# 1091500             1          1      0       1       0           0    1
# 553850              1          0      0       1       0           0    0
# 1245620             1          0      0       1       0           0    1
#
#          Story Rich  2D  Strategy  ...  Puzzle  Female Protagonist  \
# index                              ...
# 359550            0   0         1  ...       0                   0
# 252490            0   0         0  ...       0                   0
# 1091500           1   0         0  ...       0                   0
# 553850            0   0         0  ...       0                   0
# 1245620           0   0         0  ...       0                   0
#
#          Open World  Sci-fi  Action-Adventure  Pixel Graphics  Funny  \
# index
# 359550            0       0                 0               0      0
# 252490            1       0                 0               0      0
# 1091500           1       1                 0               0      0
# 553850            1       1                 0               0      0
# 1245620           1       0                 0               0      0
#
#          Third Person  Shooter  Co-op
# index
# 359550              0        1      1
# 252490              0        1      1
# 1091500             0        0      0
# 553850              1        1      1
# 1245620             1        0      1
#
# [5 rows x 30 columns]

# %% [markdown]
# Everything looks good--add these to the model list

# %%
model_df_list['tags_num'] = tags_num_df
model_df_list['tags_bool'] = tags_bool_df
model_df_list.keys()
# Out:
# dict_keys(['main', 'categories', 'tags_num', 'tags_bool'])

# %% [markdown]
# ## <span style="color: Teal; font-weight: bold">Correlations</span>
#
# Below are the correlations for the final predictors and targets for the model.

# %%
mainline_model = ['website_bool', 'support_url_bool', 'supported_languages_int', 'full_audio_languages_int', 'tags_count']
target_features = ['metacritic_bool', 'recommendations_bool', 'estimated_owners_tri', 'price_sqrt']

# %%
sns.heatmap(mainline_df[mainline_model+target_features].corr(), annot = True, cmap = "coolwarm")
plt.title('Correlations - Mainline Features')
plt.show()

# %%
plt.figure(figsize = (14, 14))
sns.heatmap(round(pd.concat([catgen_df, mainline_df[target_features]], axis = 1).corr(),1), annot = True, cmap = "coolwarm")
plt.title('Correlations - Categorical')
plt.show()

# %%
plt.figure(figsize = (16, 16))
sns.heatmap(round(pd.concat([tags_num_df, mainline_df[target_features]], axis = 1).corr(),1), annot = True, cmap = "coolwarm")
plt.title('Correlations - Tags (Numerical)')
plt.show()

# %%
plt.figure(figsize = (16, 16))
sns.heatmap(round(pd.concat([tags_bool_df, mainline_df[target_features]], axis = 1).corr('spearman'),1), annot = True, cmap = "coolwarm")
plt.title('Correlations - Tags (Boolean)')
plt.show()

# %% [markdown]
# # <span style="color: Teal; font-weight: bold">Save for Export</span>

# %%
#mainline_df.to_csv('data/model_mainline games.csv', index = True)
#catgen_df.to_csv('data/model_catgen.csv', index = True)
#tags_num_df.to_csv('data/model_tags_numeric.csv', index = True)
#tags_bool_df.to_csv('data/model_tags_bool.csv', index = True)
